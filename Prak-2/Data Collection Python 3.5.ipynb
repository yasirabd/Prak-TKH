# %% [markdown]
# # Data Collection

# %% [markdown]
# <i>Data Collection</i> adalah proses pengumpulan sejumlah data yang banyak.
# Pada proses <i>Data Collection</i>, kita dapat menggunakan berbagai macam tools atau software misalanya menggunakan Web Data Collection Tool : [import.io](https://www.import.io/)
# <br><br>
# Pada praktikum kali ini, dengan menggunakan bahasa python untuk melakukan pengkoleksian data.

# %% [markdown]
# ### 1. Twitter
# Pada pengambilan data tweet di twitter memanfaatkan <i>Application Programming Interface</i> (API) dari Twitter yang bersifat <i>open source</i>.
#
# #### a. Register App
# Lakukan register app di [sini](http://apps.twitter.com).
# Pastikan mendapatkan <i>Consumer Key (API Key), Consumer Secret (API Secret), Access Token,</i> dan <i>Access Token Secret </i>.
#
# #### b. Install Tweepy (Python Library for Accessing Twitter-API)
# Untuk meng-install dapat menggunakan <u>pip install tweepy</u>.
# Dokumentasi mengenai tweepy bisa diakses di [sini](http://docs.tweepy.org/en/v3.5.0/)

# %% [markdown]
# #### c. OAuth
# Lakukan inisialisasi untuk melakukan OAuth pada API Twitter

# %%
import tweepy
from tweepy import OAuthHandler
 
consumer_key = 'tVv1t7anKZTmZvE3i7sbkP4Wd'
consumer_secret = 'selmdJRa0BK9MT7sOX4BCLmAz9VzjSJvWkrhCb3W6564dTiEvX'
access_token = '477563933-KMDYT9D3sTwOrhuiSxXUcHBgVU7oKlt5hRdwyRBT'
access_secret = 'AVDVzXVxXORD66rWPkloBdljHGRkBRzVAkXjmMlh3CE1Z'
     
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %% [markdown]
# Variable <u>api</u> akan menjadi gerbang untuk akses pada API Twitter.
#
# - Berikut ini adalah salah satu contoh yang digunakan untuk menampilkan 10 items tweet pada <u>home timeline</u>.

# %%
from tweepy import Cursor

i = 1
for status in Cursor(api.home_timeline).items(10):
    # Process a single status
    print(i, status.text)
    i+=1
# Out:
# 1 Tiket early bird 50K dan OTS 65K termasuk seminar kit, sertifikat, lunch, dan snack. Info: https://t.co/b8EcpWX6yM… https://t.co/b6cLmZCmN6
# 2 Lionel Messi has made shocking remarks about Man United. They will hate him for this! https://t.co/BFS0kwUMKt https://t.co/EXX3Q6evaf
# 3 https://t.co/iaXDw3yvId [#wowfakta] Faktagram hari ini #fakta #faktanya #mostpopular via instagram https://t.co/iBIatgag03
# 4 A folding #iPhone could be in your future https://t.co/bOKzY1hW0v https://t.co/4N4sx8AZEA
# 5 Juve Memang Hobi Mempersulit Diri Sendiri
# https://t.co/Sdaifbsl7m
# 6 #lalinBDG 12.28 : Suci arah gasibu ramai lancar, cuaca mendung https://t.co/7sHCeY0mLg
# 7 Microsoft Teams: 7 things you need to know https://t.co/6QPGuLvzj0 https://t.co/nWqjMqQQyM
# 8 Semalem temen2 main Overwatch nginep di rumah. Hari ini ngopi bareng. Yg baju merah masih 17 thn.. :D https://t.co/rbkRNdkFah
# 9 RT @mojokstore: Kakak @BukuMojok mau ulang tahun. Blio gak mau berbahagia sendiri. Warbyasaa ya. Yuk, diborong, mumpung ihikk 😝😝
#
# #SetahunB…
# 10 Bayi yg memiliki orang tua yg gemar menonton TV mmiliki keterlambatan dlm perkembangan verbal. [Archives of Pediatric &amp; Adolescent Medicine]

# %% [markdown]
# - Menampilkan atribut dari satu tweet

# %%
for status in Cursor(api.home_timeline).items(1):
    # Process a single status
    print(status)
# Out:
# Status(coordinates=None, favorited=False, created_at=datetime.datetime(2016, 11, 3, 5, 30, 29), source_url='http://www.hootsuite.com', id=794049085774921728, in_reply_to_user_id_str=None, in_reply_to_status_id_str=None, entities={'user_mentions': [], 'symbols': [], 'urls': [{'expanded_url': 'http://www.economixfebui.com', 'display_url': 'economixfebui.com', 'url': 'https://t.co/b8EcpWX6yM', 'indices': [91, 114]}, {'expanded_url': 'https://twitter.com/i/web/status/794049085774921728', 'display_url': 'twitter.com/i/web/status/7…', 'url': 'https://t.co/b6cLmZCmN6', 'indices': [116, 139]}], 'hashtags': []}, favorite_count=0, place=None, in_reply_to_user_id=None, author=User(name='GoodNewsFrmIndonesia', protected=False, favourites_count=2778, profile_background_color='BE2021', profile_sidebar_border_color='FFFFFF', profile_banner_url='https://pbs.twimg.com/profile_banners/39677695/1447664505', is_translator=False, follow_request_sent=False, profile_image_url='http://pbs.twimg.com/profile_images/666179558073176064/JIe_Vb0X_normal.png', profile_link_color='BE2021', notifications=False, id_str='39677695', friends_count=586, following=True, has_extended_profile=False, utc_offset=25200, profile_sidebar_fill_color='DDEEF6', geo_enabled=False, default_profile_image=False, profile_image_url_https='https://pbs.twimg.com/profile_images/666179558073176064/JIe_Vb0X_normal.png', verified=True, created_at=datetime.datetime(2009, 5, 13, 3, 28, 42), translator_type='regular', id=39677695, profile_background_image_url_https='https://pbs.twimg.com/profile_background_images/378800000072875143/ea259d5b25a3c103294540e738416d88.png', profile_background_tile=False, entities={'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'https://www.goodnewsfromindonesia.id', 'display_url': 'goodnewsfromindonesia.id', 'url': 'https://t.co/LpUQl5XGvi', 'indices': [0, 23]}]}}, is_translation_enabled=False, profile_use_background_image=True, profile_background_image_url='http://pbs.twimg.com/profile_background_images/378800000072875143/ea259d5b25a3c103294540e738416d88.png', description='Restoring Optimism, Rebuilding Confidence\nEmail : GNFI[at]goodnews[dot]id | \nInstagram : GNFI | \nLINE : @GNFI | \nFacebook Page : Good News From Indonesia', followers_count=938051, _json={'profile_image_url_https': 'https://pbs.twimg.com/profile_images/666179558073176064/JIe_Vb0X_normal.png', 'verified': True, 'created_at': 'Wed May 13 03:28:42 +0000 2009', 'name': 'GoodNewsFrmIndonesia', 'protected': False, 'utc_offset': 25200, 'id': 39677695, 'profile_use_background_image': True, 'profile_background_color': 'BE2021', 'profile_sidebar_border_color': 'FFFFFF', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000072875143/ea259d5b25a3c103294540e738416d88.png', 'profile_background_tile': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/39677695/1447664505', 'is_translator': False, 'entities': {'description': {'urls': []}, 'url': {'urls': [{'expanded_url': 'https://www.goodnewsfromindonesia.id', 'display_url': 'goodnewsfromindonesia.id', 'url': 'https://t.co/LpUQl5XGvi', 'indices': [0, 23]}]}}, 'profile_link_color': 'BE2021', 'follow_request_sent': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/666179558073176064/JIe_Vb0X_normal.png', 'translator_type': 'regular', 'is_translation_enabled': False, 'geo_enabled': False, 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000072875143/ea259d5b25a3c103294540e738416d88.png', 'notifications': False, 'following': True, 'description': 'Restoring Optimism, Rebuilding Confidence\nEmail : GNFI[at]goodnews[dot]id | \nInstagram : GNFI | \nLINE : @GNFI | \nFacebook Page : Good News From Indonesia', 'id_str': '39677695', 'friends_count': 586, 'followers_count': 938051, 'listed_count': 1548, 'default_profile': False, 'has_extended_profile': False, 'contributors_enabled': False, 'favourites_count': 2778, 'profile_text_color': '3 ...

# %% [markdown]
# Bisa juga kita meletakkan file hasil <i>crawling</i> pada suatu file <i>json, csv, txt, dll</i>
#
# - JSON

# %%
import json

with open('home_timeline_35.json', 'w') as f:
    for status in Cursor(api.home_timeline).items(2):
        # Process a single status
        f.write(json.dumps(status._json)+"\n")

# %% [markdown]
# - CSV

# %%
import csv

csvFile = open('home_timeline_35.csv', 'w')
csvWriter = csv.writer(csvFile)

row = [ "user", "text" ]
csvWriter.writerow(row)

for tweet in tweepy.Cursor(api.home_timeline).items(2):
    #Write a row to the csv file/ I use encode utf-8
    csvWriter.writerow([tweet.user.screen_name, tweet.text.encode('utf-8')])
csvFile.close()

# %% [markdown]
# - TXT

# %%
import sys

with open('home_timeline_35.txt', 'w') as txt:
    for status in Cursor(api.home_timeline).items(2):
        # Process a single status
        txt.write(status.user.screen_name + "\n")

# %% [markdown]
# #### d. Twitter Streaming
# Pada proses ini kita mendapatkan data dengan melakukan stream langsung untuk pengambilan tweet.

# %%
from tweepy import Stream

class MyStreamListener(tweepy.StreamListener): 
    def on_data(self, kicau):
        print(kicau)
 
    def on_error(self, status_code):
        if status_code == 420:
            #returning False in on_data disconnects the stream
            return False
        
myStream = tweepy.Stream(auth = api.auth, listener = MyStreamListener())

myStream.filter(track=['python'], async=True)

# %% [markdown]
# ### 2. Wikipedia
# Wikipedia juga menyediakan API untuk mengakses/mengambil data yang kita butuhkan.
#
# #### a. Install Library Wikipedia
# Untuk meng-install menggunakan <u>pip install wikipedia</u>. Untuk dokumentasi bisa diakses di [sini](https://wikipedia.readthedocs.io/en/latest/quickstart.html)

# %%
import wikipedia

wikipedia.set_lang("id")

# %% [markdown]
# - Search

# %%
print (wikipedia.search("Semarang"))
# Out:
# ['Kota Semarang', 'Semarang Utara, Semarang', 'Semarang Barat, Semarang', 'Semarang Timur, Semarang', 'Semarang Tengah, Semarang', 'Bergas, Semarang', 'Suruh, Semarang', 'Getasan, Semarang', 'Ungaran Timur, Semarang', 'Manyaran, Semarang Barat, Semarang']

# %% [markdown]
# - Suggest

# %%
print (wikipedia.suggest("Semarng"))
# Out:
# semarang

# %% [markdown]
# - Summary

# %%
print (wikipedia.summary("Semarang", sentences=1))
# Out:
# Kota Semarang (Hanacaraka: ꦑꦸꦛꦯꦼꦩꦫꦁ) adalah ibukota Provinsi Jawa Tengah, Indonesia sekaligus kota metropolitan terbesar kelima di Indonesia sesudah Jakarta, Surabaya, Bandung, dan Medan.

# %% [markdown]
# - Page

# %%
page = wikipedia.page("Semarang")

print (page.title)
print (page.url)
print (page.content)
# Out:
# Kota Semarang
# https://id.wikipedia.org/wiki/Kota_Semarang
# Kota Semarang (Hanacaraka: ꦑꦸꦛꦯꦼꦩꦫꦁ) adalah ibukota Provinsi Jawa Tengah, Indonesia sekaligus kota metropolitan terbesar kelima di Indonesia sesudah Jakarta, Surabaya, Bandung, dan Medan. Sebagai salah satu kota paling berkembang di Pulau Jawa, Kota Semarang mempunyai jumlah penduduk yang hampir mencapai 2 juta jiwa dan siang hari bisa mencapai 2,5 juta jiwa. Bahkan, Area Metropolitan Kedungsapur (Kendal, Demak, Ungaran Kabupaten Semarang, Kota Salatiga, dan Purwodadi Kabupaten Grobogan) dengan penduduk sekitar 6 juta jiwa, merupakan Wilayah Metropolis terpadat keempat, setelah Jabodetabek (Jakarta), Gerbangkertosusilo (Surabaya), dan Bandung Raya. Dalam beberapa tahun terakhir, perkembangan Semarang ditandai pula dengan munculnya beberapa gedung pencakar langit di beberapa sudut kota. Sayangnya, pesatnya jumlah penduduk membuat kemacetan lalu lintas di dalam Kota Semarang semakin macet. Kota Semarang dipimpin oleh wali kota Hendrar Prihadi, S.E, M.M dan wakil wali kota Ir. Hj. Hevearita Gunaryanti Rahayu. Kota ini terletak sekitar 558 km sebelah timur Jakarta, atau 312 km sebelah barat Surabaya, atau 621 km sebalah barat daya Banjarmasin (via udara). Semarang berbatasan dengan Laut Jawa di utara, Kabupaten Demak di timur, Kabupaten Semarang di selatan, dan Kabupaten Kendal di barat.Luas Kota 373.67 km2.
#
#
# == Geografi ==
# Daerah dataran rendah di Kota Semarang sangat sempit, yakni sekitar 4 kilometer dari garis pantai. Dataran rendah ini dikenal dengan sebutan kota bawah. Kawasan kota bawah seringkali dilanda banjir, dan di sejumlah kawasan, banjir ini disebabkan luapan air laut (rob). Di sebelah selatan merupakan dataran tinggi, yang dikenal dengan sebutan kota atas, di antaranya meliputi Kecamatan Candi, Mijen, Gunungpati, Tembalang dan Banyumanik. Pusat pertumbuhan di Semarang sebagai pusat aktivitas dan aglomerasi penduduk muncul menjadi kota kecil baru, seperti di Semarang bagian atas tumbuhnya daerah Banyumanik sebagai pusat aktivitas dan aglomerasi penduduk Kota Semarang bagian atas menjadikan daerah ini cukup padat. Fasilitas umum dan sosial yang mendukung aktivitas penduduk dalam bekerja maupun sebagai tempat tinggal juga telah terpenuhi. Banyumanik menjadi pusat pertumbuhan baru di Semarang bagian atas, dikarenakan munculnya aglomerasi perumahan di daerah ini. Dahulunya Banyumanik hanya merupakan daerah sepi tempat tinggal penduduk Semarang yang bekerja di Semarang bawah (hanya sebagai dormitory town). Namun saat ini daerah ini menjadi pusat aktivitas dan pertumbuhan baru di Kota Semarang, dengan dukungan infrastruktur jalan dan aksessibilitas yang terjangkau. Fasilitas perdagangan dan perumahan baru banyak bermunculan di daerah ini, seperti Carefour, Mall Banyumanik, Ada Swalayan, Perumahan Banyumanik, Perumahan Pucang Gading, dan fasilitas pendidikan baik negeri maupun swasta, seperti Undip, Polines, Unika, dll, dengan dukungan akses jalan tol dan terminal moda yang memperlancar transportasi. Cepatnya pertumbuhan di daerah ini dikarenakan kondisi lahan di Semarang bawah sering terkena bencana rob banjir.
#
#
# == Sejarah ==
#
# Sejarah Semarang berawal kurang lebih pada abad ke-6 M, yaitu daerah pesisir yang bernama Pragota (sekarang menjadi Bergota) dan merupakan bagian dari kerajaan Mataram Kuno. Daerah tersebut pada masa itu merupakan pelabuhan dan di depannya terdapat gugusan pulau-pulau kecil. Akibat pengendapan, yang hingga sekarang masih terus berlangsung, gugusan tersebut sekarang menyatu membentuk daratan. Bagian kota Semarang Bawah yang dikenal sekarang ini dengan demikian dahulu merupakan laut. Pelabuhan tersebut diperkirakan berada di daerah Pasar Bulu sekarang dan memanjang masuk ke Pelabuhan Simongan, tempat armada Laksamana Cheng Ho bersandar pada tahun 1435 M. Di tempat pendaratannya, Laksamana Cheng Ho mendirikan kelenteng dan mesjid yang sampai sekarang masih dikunjungi dan disebut Kelenteng Sam Po Kong (Gedung Batu).
# Pada akhir abad ke-15 M ada seseorang ditempatkan oleh Kerajaan Demak, dikenal sebagai Pangeran Made Pandan (Sunan Pandanaran I), untuk menyebarkan agama Islam dari perbukitan Pragota. Dari waktu ke waktu daerah itu semakin subur, dari sela-sela kesuburan itu muncullah pohon asam yang arang (bahasa Jawa: Asem Arang), sehingga memberikan gelar atau nama daerah itu menjadi Semarang.
#
# Sebagai pendiri desa, kemudian menjadi kepala daerah setempat, dengan gelar Kyai Ageng Pandan Arang I. Sepeninggalnya, pimpinan daerah dipegang oleh putranya yang bergelar Pandan Arang II (kelak disebut sebagai Sunan Bayat atau Sunan Pandanaran II atau Sunan Pandanaran Bayat atau Ki Ageng Pandanaran atau Sunan Pandanaran saja). Di bawah pimpinan Pandan Arang II, daerah Semarang semakin menunjukkan pertumbuhannya yang meningkat, sehingga menarik perhatian Sultan Hadiwijaya dari Pajang. Karena persyaratan peningkatan daerah dapat dipenuhi, maka diputuskan untuk menjadikan Semarang setingkat dengan Kabupaten. Pada tanggal 2 Mei 1547 bertepatan dengan peringatan maulid Nabi Muhammad SAW, tanggal 12 rabiul awal tahun 954 H disahkan oleh Sultan Hadiwijaya setelah berkonsultasi dengan Sunan Kalijaga. Tanggal 2 Mei kemudian ditetapkan sebagai hari jadi kota Semarang.
#
# Kemudian pada tahun 1678 Amangkurat II dari Mataram, berjanji kepada VOC untuk memberikan Semarang sebagai pembayaran hutangnya, dia mengklaim daerah Priangan dan pajak dari pelabuhan pesisir sampai hutangnya lunas. Pada tahun 1705 Susuhunan Pakubuwono I menyerahkan Semarang kepada VOC sebagai bagian dari perjanjiannya karena telah dibantu untuk merebut Kartasura. Sejak saat itu Semarang resmi menjadi kota milik VOC dan kemudian Pemerintah Hindia Belanda.
# Pada tahun 1906 dengan Stanblat Nomor 120 tahun 1906 dibentuklah Pemerintah Gemeente. Pemerintah kota besar ini dikepalai oleh seorang Burgemeester (Wali kota). Sistem Pemerintahan ini dipegang oleh orang-orang Belanda berakhir pada tahun 1942 dengan datangya pemerintahan pendudukan Jepang.
# Pada masa Jepang terbentuklah pemerintah daerah Semarang yang dikepalai Militer (Shico) dari Jepang. Didampingi oleh dua orang wakil (Fuku Shico) yang masing-masing dari Jepang dan seorang bangsa Indonesia. Tidak lama sesudah kemerdekaan, yaitu tanggal 15 sampai 20 Oktober 1945 terjadilah peristiwa kepahlawanan pemuda-pemuda Semarang yang bertempur melawan balatentara Jepang yang bersikeras tidak bersedia menyerahkan diri kepada Pasukan Republik. Perjuangan ini dikenal dengan nama Pertempuran Lima Hari.
# Tahun 1946 Inggris atas nama Sekutu menyerahkan kota Semarang kepada pihak Belanda. Ini terjadi pada tanggal l6 Mei 1946. Tanggal 3 Juni 1946 dengan tipu muslihatnya, pihak Belanda menangkap Mr. Imam Sudjahri, wali kota Semarang sebelum proklamasi kemerdekaan. Selama masa pendudukan Belanda tidak ada pemerintahan daerah kota Semarang. Namun para pejuang di bidang pemerintahan tetap menjalankan pemerintahan di daerah pedalaman atau daerah pengungsian di luar kota sampai dengan bulan Desember 1948. daerah pengungsian berpindah-pindah mulai dari kota Purwodadi, Gubug, Kedungjati, Salatiga, dan akhirnya di Yogyakarta. Pimpinan pemerintahan berturut-turut dipegang oleh R Patah, R.Prawotosudibyo dan Mr Ichsan. Pemerintahan pendudukan Belanda yang dikenal dengan Recomba berusaha membentuk kembali pemerintahan Gemeente seperti pada masa kolonial dulu di bawah pimpinan R Slamet Tirtosubroto. Hal itu tidak berhasil, karena dalam masa pemulihan kedaulatan harus menyerahkan kepada Komandan KMKB Semarang pada bulan Februari 1950. tanggal I April 1950 Mayor Suhardi, Komandan KMKB. menyerahkan kepemimpinan pemerintah daerah Semarang kepada Mr Koesoedibyono, seorang pegawai tinggi Kementerian Dalam Negeri di Yogyakarta. Ia menyusun kembali aparat pemerintahan guna memperlancar jalannya pemerintahan.
#
#
# == Ekonomi ==
# Ekonomi Kota Semarang cukup besar karena statusnya sebagai ibu kota provinsi Jawa Tengah. Perekonomian Kota Semarang menurut data BPS 2012 didominasi sektor Industri dan sektor Perdagangan:43; PDRB (Produk Domestik Regional Bruto) 2012 atas dasar harga berlaku mencapai Rp. 54,38 Triliun.:38-39 Pertumbuhan ekonomi yang tinggi ditandai dengan banyaknya gedung tinggi berupa hotel, kantor dan apartemen di Kota Semarang; Daftar gedung tertinggi di Semarang menunjukkan Kota Semarang memiliki 30 gedung dengan ketinggian minimal 12 lantai dan 75 gedung dengan ketinggian berkisar antara 7-11 lantai.
#
#
# === Kawasan Bisnis Terpadu - Central Business Districts (CBD) ===
# Sebagai ibukota provinsi Jawa Tengah dan kota metropolitan terbesar kelima di wilayah Republik Indonesia, Semarang telah bertransformasi dan berubah berdinamika menuju kearah yang lebih baik lagi. Dalam kurung waktu kurang dari 10 tahun Metropolitan Semarang terus membangun mempunyai andil dalam finansial yang vital di Indonesia dikarenakan sektor perdagangan dan industri serta jasanya yang berkembang. Sebagai konsekuensinya daya beli masyarakat meningkat, arus modal masuk, indeks kepercayaan konsumen dan doing business yang relatif kondusif berkembang beberapa Kawasan Bisnis Terpadu atau CBD (Central Business District). Beberapa CBD yang masuk dalam kawasan prime segitiga emas antara lain.
#
#
# === Simpang Lima City Center (SLCC) ===
#
# Simpang Lima Ciy Center (SLCC) adalah salah satu Central Business District (CBD) atau Kawasan Bisnis Terpadu yang terletak di Semarang Pusat dan salah satu CBD yang berkembang di jantung kota Semarang. Tidak heran apabila banyak bangunan-bangunan jangkung atau biasa disebut pencakar langit hadir dikawasan ini. Beberapa signature building yang menjadi ciri khas dari SLCC Semarang adalah Ciputa Swiss-Belhotel International Hotel Semarang, Ciputra Mall, Horison Hotel, Plaza Simpang Lima, Louis Kienne Serviced Apartment Hotel, HA-KA Hotel (coming soon), Santika Premiere Hotel, Wisma HSBC, INDOSAT Oooredoo Tower, Living Plaza ACE Hardware & InForma, Gramedia Center Pandanaran, Accor Ibis Simpang Lima Hotel, Amaris Simpang Lima Hotel, Tentrem MIxed-Use Tower (coming soon), Simpang Lima Residences, SMC (Semarang Medical Centerl) Telogorejo Hospital, Pandanaran Hotel, DBS Center, @Hom Hotel, SentraLand Superblock, Graha Bank Indonesia, Plaza Telkom, WIsma Telkomsel, XL Axiata Center Simpang Lima, Bank Mandiri Plaza, CitiBank Square, Pramuka Building,
#
#
# === Pemuda Central Business District (PCBD) ===
#
# Lawang Sewu Heritage Complex, Semarang Tourism Center, Pandanaran Building, Danamon Tower, Wisma BII Maybank, Menara Juang 45, Wisma Sucofindo (FWD & DanaReksa), DP Mall, SmartFren Galeri, Bank Panin Plaza, Menara Suara Merdeka, Premier Inn Hotel Office Tower (coming soon), The Pinnacle Apartment Tower, Menara Bank Mega, Manulife Building, ANZ Square, Graha BRI, House of Indonesia Stock Exchange (IDX) Pandanaran, Dafam Hotel, Graha Bina Artha (Bank JaTeng headquarter), Amaris Hotel, Gramedia Plaza Pemuda, Paragon City Mall, Crowne Plaza Hotel, Accor Novotel Hotel, Whiz Hotel, CitraDream Hotel, Accor Ibis Budget Hotel, Menara Bank Mandiri, Wisma BCA, Marquis de Lafayette Pollux, Sri Ratu Plaza.
#
#
# === Gajahmada Golden Triangle (GGT) ===
# Kawasan Budaya Tionghoa (Pecinan) Semarang - Semarang Chinatown Heritage Complex, Gumaya Tower Hotel, ACE Gajahmada, MG Suites Maven Hotel & Residences, Chanti Hotel, Semarang Town Square (SETOS), 3 Store Gajahmada, Grandhika Hotel.
#
#
# == Daftar wali kota ==
#
#
# === Sejak 1945 ===
# Sejak tahun 1945 para wali kota yang memimpin kota besar Semarang yang kemudian menjadi Kota Praja dan akhirnya menjadi Kota Semarang adalah sebagai berikut:
# Mr. Moch.lchsan (1945-1949)
# Mr. Koesoedibiyono Tjondrowibowo (1949–1 Juli 1951)
# RM. Hadisoebeno Sosrowerdoyo (1 Juli 1951–1 Januari 1958)
# Mr. Abdulmadjid Djojoadiningrat (7 Januari 1958–1 Januari 1960)
# RM Soebagyono Tjondrokoesoemo (1 Januari 1961–26 April 1964)
# Mr. Wuryanto (25 April 1964–1 September 1966)
# Letkol. Soeparno (1 September 1966–6 Maret 1967)
# Letkol. R. Warsito Soegiarto (6 Maret 1967–2 Januari 1973)
# Kolonel Hadijanto (2 Januari 1973–15 Januari 1980)
# Kol. H. Iman Soeparto Tjakrajoeda SH (15 Januari 1980–19 Januari 1990)
# Kol. H. Soetrisno Suharto (19 Januari 1990–19 Januari 2000)
# H. Sukawi Sutarip SH. (19 Januari 2000–2010)
# Drs. H. Soemarmo HS, MSi. (2010–2013)
# Hendrar Prihadi, SE, MM. (2013-2015; 2016-sekarang)
# Tavip Supriyanto (Pejabat Sementara, 2015-2016)
#
#
# == Daftar penguasa Semarang ==
#
#
# === Di bawah Kerajaan Demak ===
# Kin San/Raden Kusen (1478-1529)
# Ki Ageng Pandan Arang
# Sunan Bayat (Sunan Pandan Arang II)
#
#
# === Di bawah Kesultanan Pajang dan Kesultanan Mataram ===
# Pangeran Kanoman atau Pandan Arang III (1553-1586)
# Mas R.Tumenggung Tambi (1657-1659)
# Mas Tumenggung Wongsorejo (1659 - 1666)
# Mas Tumenggung Prawiroprojo (1666-1670)
# Mas Tumenggung Alap-alap (1670-1674)
# Kyai Mertonoyo, Kyai Tumenggung Yudonegoro atau Kyai Adipati Suromenggolo (1674 -1701)
#
#
# === Di bawah VOC ===
# Raden Martoyudo atau Raden Sumoningrat (1743-1751)
# Marmowijoyo atau Sumowijoyo atau Sumonegoro atau Surohadimenggolo (1751-1773)
# Surohadimenggolo IV (1773-?)
# Adipati Surohadimenggolo V atau kanjeng Terboyo (?)
#
#
# === Pemerintahan Hindia Belanda ===
# Raden Tumenggung Surohadiningrat (?-1841)
# Putro Surohadimenggolo (1841-1855)
# Mas Ngabehi Reksonegoro (1855-1860)
# RTP Suryokusurno (1860-1887)
# RTP Reksodirjo (1887-1891)
# RMTA Purbaningrat (1891-?)
# Pemerintahan kemudian dibagi dua, yakni Kota Praja dan Kabupaten. Penguasa pribumi kemudian menjadi Bupati Semarang:
# Raden Cokrodipuro (?-1927)
# RM Soebiyono (1897-1927)
# RM Amin Suyitno (1927-1942)
# RMAA Sukarman Mertohadinegoro (1942-1945)
# Sementara penguasa Belanda menjadi Wali Kota Semarang:
# D. de Jongh (1916-1927)
# A. Bagchus (1928-1935)
# H.E. Boissevain (1936-1942)
#
#
# === Pemerintahan Republik Indonesia ===
# R. Soediyono Taruna Kusumo (1945-1945), hanya berlangsung satu bulan
# M. Soemardjito Priyohadisubroto (tahun 1946)
#
#
# === Pemerintahan Republik Indonesia Serikat ===
# RM. Condronegoro hingga tahun 1949
#
#
# === Setelah pengakuan kedaulatan ===
# M. Soemardjito Priyohadisubroto (1946-1952)
# R. Oetoyo Koesoemo (1952-1956).
# Untuk bupati selanjutnya lihat Kabupaten Semarang.
# Kotamadya Semarang secara definitif ditetapkan berdasarkan UU Nomor 13 tahun 1950 tentang pembentukan kabupaten-kabupaten dalam lingkungan Provinsi Jawa Tengah.
#
#
# == Pembagian administratif ==
# Kota Semarang terdiri atas 16 kecamatan dan 177 kelurahan
#
#
# == Perwakilan ==
# DPRD Kota Semarang hasil Pemilihan Umum Legislatif 2014 tersusun dari 9 partai, dengan perincian sebagai berikut:
#
#
# == Penduduk ==
# Penduduk Semarang umumnya adalah suku Jawa dan menggunakan Bahasa Jawa sebagai bahasa sehari-hari. Agama mayoritas yang dianut adalah Islam. Semarang memiliki komunitas Tionghoa yang besar. Seperti di daerah lainnya di Jawa, terutama di Jawa Tengah, mereka sudah berbaur erat dengan penduduk setempat dan menggunakan Bahasa Jawa dalam berkomunikasi sejak ratusan tahun silam.
#
#
# == Julukan ==
# Kota Semarang mempunyai mempunyai beberapa julukan, antara lain:
# Venetië van Java
# Semarang dilalui banyak sungai di tengah kota seperti di Venesia (Italia), sehingga Belanda menyebut Semarang sebagai Venetië van Java.
# Kota Lumpia
# Lumpia adalah makanan khas Semarang, yang terbuat dari akulturasi 2 budaya yaitu budaya Jawa dan China.
# Kota Atlas
# Semarang memiliki semboyan Kota ATLAS akronim (Aman, Tertib, Lancar, Asri dan Sehat), sebagai slogan pemeliharaan keindahan kota.
# The Port of Java
# Untuk kepentingan pemasaran pariwisata, Wali Kota Semarang mengambil slogan pariwisata Semarang, The Port of Java (Pelabuhannya Jawa) sebagai upaya pencitraan kota Semarang sebagai pusat Pelabuhan Jawa. Karena Setiap orang yang hendak pergi dari Jakarta atau Jawa Barat ke Surabaya atau Jawa Timur dan juga sebaliknya, harus melewati dan singgah di Kota Semarang. Bahkan menurut sejarah Laksamana Ceng Ho pun berlabuh di Kota Semarang untuk singgah.
# Semarang Pesona Asia
# Pada tahun 2009 dari wacana beberapa pihak, Wali Kota Semarang menyetujui slogan "SPA", di mana konsekuensinya, dilakukan pembersihan dan pembangunan di mana mana, (perbaikan saluran, jalan, trotoar, taman, penataan pkl)
#
#
# == Pariwisata ==
#
#
# === Wisata Alam ===
# Pulau Tirangcawang, di Kelurahan Tugu
# Pantai Tirang, di Kelurahan Tambak Harjo
# Pantai Marina, di Kelurahan Tawangsari
# Pantai Maron, di Kelurahan Tambak Harjo
# Goa Kreo, di Kelurahan Kandri
# Taman Lele Semarang, di Kelurahan Tambakaji
# Curug Lawe di Gunungpati
# Curug Benowo di Gunungpati
#
#
# === Wisata sejarah ===
# Museum MURI, di Kelurahan Tegalsari
# Museum Perkembangan Islam Jawa Tengah, di Kelurahan Tegalsari
# Museum Jamu Nyonya Meneer, di Kelurahan Muktiharjo
# Museum Jawa Tengah, di Kelurahan Gisikdrono
# Museum Mandala Bhakti, di Kelurahan Pindrikan Kidul
# Lawang Sewu, di Kelurahan Pindrikan Kidul
# Tugu Muda, di Kelurahan Pindrikan Kidul
# Candi Tugu, di Kelurahan Tugurejo
# Little Netherland (Kota Tua Semarang), di Kelurahan Purwodinatan
#
#
# === Wisata religius ===
#
# Masjid Agung Jawa Tengah, di Kelurahan Sambirejo
# Masjid Baiturrahman Semarang, di Simpanglima
# Masjid Kauman Semarang, di daerah Kauman, Johar
# Klenteng Sam Po Kong, di daerah Simongan
# Kelenteng Tay Kak Sie Tri Dharma, di Gang Lombok, Semarang Pusat
# Gereja Blenduk, di Kecamatan Semarang Utara
# Gereja Katedral Semarang di Kelurahan Randusari
# Gereja JKI Injil Kerajaan Semarang di Kelurahan Tawangsari
# Vihara Mahavira Graha di Kelurahan Tawangsari
# Pagoda Buddhagaya, di Pudak Payung, Banyumanik, Semarang Selatan
#
#
# === Wisata keluarga ===
# Wonderia, di Kelurahan Tegalsari
# Kebun Binatang Mangkang, di Kelurahan Mangkang Kulon
# Taman Mini Jawa Tengah (Maerokoco), di Kelurahan Tawangsari
#
#
# === Wisata belanja ===
# Pasar Johar, di Kelurahan Kauman
# Mall Ciputra (Ramayana), Simpang Lima City Center
# Simpang Lima Plaza (Matahari), Simpang Lima City Center
# Java Super Mall (Hypermart), di Kelurahan Peterongan
# Paragon City Mall (Matahari), Pemuda Central Business District (PCBD) di Kelurahan Sekayu
# Sri Ratu (Matahari), di Kelurahan Peterongan
# DP Mall (Carrefour), di Kelurahan Pekunden Jl. Pemuda Semarang Tengah
# M-Art Shop, Jl. Mataram 653 Semarang
#
#
# == Perayaan ==
# Kota Semarang memiliki beberapa event perayaan, yaitu:
# Dugderan
# Semarang Expo
# Semarang Great Sale
# Semarang Fashion Festival
# Semarang Fashion On The Street
# Festival Kota Lama Semarang
#
#
# == Kuliner ==
#
#
# === Masakan ===
# Makanan khas Semarang antara lain adalah:
# Bandeng presto
# Soto Bangkong "Soto Semarang"
# Mie Kopyok
# Nasi pindang
# Nasi Ayam Semarang
# Sega Becak
# Sega Lunyu
# Tahu Pong
# Pecel Koyor
# Tahu Petis
# Tahu Gimbal
#
#
# === Jajanan ===
#
# Jajanan Pasar khas Semarang antara lain adalah:
# Madu Semarang
# Lunpia Semarang
# Wingko Babat
# Spekoek
# Jongkong Singkong
# Gandos
# Kue Moci
# Blanggem
# Mentho
# Timus
# Gilo-gilo
# Bakpia
# Tahu Gimbal
#
#
# === Minuman ===
# Minuman khas Semarang antara lain adalah:
# Es Cao
# Es Congklik
# Wedang tahu
# Wedang Jahe
# Wedang Ronde
# Wedang Kacang Tanah
# Wedang Durian
# Wedang Jalang (Wedang Jahe Alang-alang)
# Wedang Lengkeng
# Kolak Setup
#
#
# === Oleh-oleh ===
# Roti Gandjel Rel
# Lumpia
# Jambu Semarang
# Tahu Bakso Ungaran
# Mari Wijen
#
#
# == Media ==
#
#
# === Surat kabar ===
# Kota Semarang memiliki beberapa surat kabar di antaranya:
#
#
# ==== Terrestrial televisi ====
# Kota Semarang juga memiliki beberapa terdiri dari 18 stasiun televisi (15 siaran nasional & 3 siaran lokal) seperti:
#
#
# ==== Televisi berlangganan ====
# Kota Semarang juga memiliki beberapa televisi berlangganan seperti:
# Aora TV
# Astro Nusantara
# BiG TV
# Centrin TV
# Groovia TV
# UseeTV
#
# Indovision
# Top TV
# OkeVision
#
# Max3
# Nexmedia
# OrangeTV/Skynindo
#
# Transvision
# YesTV
#
# Topas TV
# Viva+
#
#
# === Radio ===
# Kota Semarang juga memiliki 42 stasiun radio seperti:
#
#
# == Sarana umum ==
#
#
# === Olahraga ===
# PSIS Semarang merupakan satu-satunya klub sepak bola profesional di Kota Semarang. Pada musim 1999, PSIS berhasil menjadi juara Liga Indonesia, namun pada musim kompetisi 2000 terdegradasi ke Divisi I. Pada musim 2006 bermain di Divisi Utama Liga Djarum Wilayah 1 dan meraih juara kedua setelah dalam final kalah 0–1 oleh Persik Kediri Pada tahun ini PSIS kembali berlaga di Indonesia Super League tanpa dana bantuan APBD sama sekali.
# Semarang United FC merupakan klub sepak bola yang mengikuti turnamen dalam ajang Liga Primer Indonesia.
# Sasana Tinju Tugu Muda Semarang merupakan sasana tinju yang membina amatir dan profesional tingkat dunia di Kota Semarang. Perjalanan Sasana Tinju Tugu Muda Semarang yang dirintis oleh Muklis Sutan Rambing Th 1970 (1976 s/d 1978)Membentuk Sasana Tinju Adam (dengan latar belakang sponsorship Bis Adam). Th 1980 (1978 s/d 1989) Membentuk Sasana Tinju Orang Tua (dengan latar belakang sponsor jamu cap Orang Tua) Selama tahun 1984 – 1985 memiliki beberapa petinju amatir dan profesional, namun kurang maksimal karena iklim pertandingan yang jarang. Rata-rata pertandingan profesional setahun sekali, saat itu Sasana Orang Tua sempat mencetak juara Nasional atas nama Agus Suyanto. Th 1990 (1989 s/d 2008). Th 1990 membentuk Sasana Tinju Bank Buana dengan konsentrasi pembinaan tinju amatir. Th 1997 ketika tinju profesional boming di televisi, Muklis Sutan Rambing mencoba fokus kepada tinju pro dengan nama Sasana Tinju Tugu Muda Semarang (Tugu Muda merupakan lambang kota Semarang). Saat itu Sasana Tinju Bank Buana tetap jalan namun konsen di Tinju amatir, untuk Tinju profesional dengan nama Sasana Tinju Tugu Muda Semarang. Pada akhir tahun 1999 Sasana Tinju Tugu Muda Semarang berhasil mencetak 3 (tiga) juara Nasional : Chris Jhon (57 Kg / kelas Bulu), Arthur Rambing (58,1 Kg / kelas Ringan Jr) dan Sonny Rambing (63 Kg / kelas Welter Jr). Karena tertarik , Sponsorship Bank Buana ikut merambah pada pembinaan tinju profesional. Lama kelamaan ketika berprestasi tingkat internasional , berubah menjadi Sasana Tinju Bank Buana Semarang, hingga tahun 2006 menjadi Sasana Tinju UOB Buana Semarang / UOB Boxing Camp (karena nama perusahaan sponsor berubah menjadi UOB Buana). Th 2009 (2008 s/d 2011)Perubahan nama Sasana menjadi Kuku Bima Energy, menurunnya minat atlet untuk berlatih mempengaruhi prestasi tinju kota Semarang kususnya Jawa Tengah menjadi minim juara. Th 2010 (2009 s/d sekarang) Perubahan nama sasana menjadi “Sasana Tinju Temujin Rambing” sebagai wujud mengenang meninggalnya putra, pelatih sekaligus promotor tinju penggerak roda pertinjuan tanah air dan Jawa Tengah (Semarang)khususnya.
#
#
# === Transportasi ===
# Kota Semarang dapat ditempuh dengan perjalanan darat, laut, dan udara. Semarang dilalui jalur pantura yang menghubungkan Jakarta dengan kota-kota di pantai utara Pulau Jawa. Saat ini sedang dibangun jalan tol yang menghubungkan Semarang dengan Solo. Angkutan bus antarkota dipusatkan di Terminal Terboyo, Kecamatan Genuk. Angkutan dalam kota dilayani oleh bus kota, angkot, dan becak. Pada tahun 2009 mulai beroperasi TransSemarang, yang juga dikenal dengan BRT (Bus Rapid Transit), sebuah moda angkutan massal meskipun tidak menggunakan jalur khusus seperti busway (Trans Jakarta) di Jakarta.
# Semarang memiliki peranan penting dalam sejarah kereta api Indonesia. Di sinilah tonggak pertama pembangunan kereta api Hindia Belanda dimulai, dengan pembangunan jalan kereta api yang dimulai dari desa Kemijen menuju desa Tanggung sepanjang 26 Km) dengan lebar sepur 1435 mm. Pencangkulan pertama dilakukan oleh Gubernur Jenderal Hindia Belanda, Mr LAJ Baron Sloet van den Beele, Jumat 17 Juni 1864. Jalan kereta api ini mulai dioperasikan untuk umum Sabtu, 10 Agustus 1867.
# Pembangunan jalan KA ini diprakarsai sebuah perusahaan swasta Naamlooze Venootschap Nederlandsch Indische Spoorweg Maatschappij (NV NISM) (terjemahan: Perseroan tak bernama Perusahaan Kereta Api Nederland-Indonesia) yang dipimpin oleh Ir JP de Bordes. Kemudian, setelah ruas rel Kemijen - Tanggung, dilanjutkan pembangunan rel yang dapat menghubungkan kota Semarang - Surakarta (110 Km), pada 10 Februari 1870. Semarang memiliki dua stasiun kereta api: Stasiun Semarang Tawang untuk kereta api kelas bisnis dan eksekutif, serta Stasiun Semarang Poncol untuk kereta api kelas ekonomi dan angkutan barang. Kereta api di antaranya jurusan Semarang-Jakarta, Semarang-Bandung, Semarang-Surabaya, Jakarta-Semarang-Jombang, Jakarta-Semarang-Malang, Semarang-Tegal, dan Semarang-Bojonegoro.
# Angkutan udara dilayani di Bandara Ahmad Yani, menghubungkan Semarang dengan sejumlah kota-kota besar Indonesia setiap harinya. Sejak tahun 2008 Bandara Ahmad Yani menjadi bandara Internasional dengan adanya penerbangan langsung ke luar negri, contohnya ke Singapura dan Kualalumpur. Pelabuhan Tanjung Mas menghubungkan Semarang dengan sejumlah kota-kota pelabuhan Indonesia; pelabuhan ini juga terdapat terminal peti kemas.
# Untuk memperlancar jalur transportasi ke arah kota/kabupaten di Jawa Tengah di Bagian Selatan terutama jalur padat Semarang-Solo, saat ini sedang dibangun Jalan Tol Semarang-Solo. Pada tahap pertama, pembangunan jalan tol tersebut telah dioperasikan sebagian, yaitu Semarang-Ungaran yang telah mulai digunakan tahun 2011. Saat ini, pembangunan jalan tol ruas Ungaran-Bawen sedang dilakukan.
#
#
# === Kesehatan (rumah sakit) ===
# Terdapat beberapa rumah sakit besar di Semarang antara lain:
# RSUP Dr. Karyadi
# RSUD Kota Semarang
# RSU Tlogorejo
# Rumah Sakit Elizabeth
# Rumah Sakit Panti Wilasa Citarum
# Rumah Sakit Panti Wilasa Dr. Cipto
# RSU PKU Muhammadiyah Roemani
# Rumah Sakit William Both
# Rumah Sakit Islam Sultan Agung
# Rumah Sakit Columbia Asia Semarang
# Rumah Sakit Nasional Diponegoro (RSND)
#
#
# === Pendidikan ===
# Semarang terdapat sejumlah perguruan tinggi ternama baik negeri maupun swasta. Bahkan berdasarkan Peringkat universitas di Indonesia menurut Webometrics terdapat 6 universitas di Semarang termasuk 100 universitas terbaik Indonesia. Berdasarkan data dari DAPODIK Kota Semarang 2010/2011, perguruan tinggi di Kota Semarang:
#
#
# ==== Perguruan tinggi negeri ====
# Perguruan tinggi negeri tersebut adalah:
# Universitas Diponegoro (UNDIP)
# Universitas Negeri Semarang (UNNES)
# Politeknik Negeri Semarang (POLINES)
# UIN Walisongo
# Politeknik Ilmu Pelayaran Semarang (P3B/BPLP/PIP)
# Politeknik Kesehatan Kemenkes Semarang (POLTEKKES Semarang)
#
#
# ==== Perguruan tinggi swasta ====
# Perguruan tinggi swasta antara lain:
# Universitas Dian Nuswantoro (UDINUS)
# Universitas Katolik Soegijapranata (UNIKA)
# Universitas STIKUBANK
# Universitas Pandanaran (UNPAND)
# STIE Totalwin Semarang
# Sekolah Tinggi Ilmu Elektronika dan Komputer Semarang (STEKOM)
# Universitas Sultan Agung (UNISSULA)
# Universitas Semarang
# Universitas 17 Agustus 1945 (UNTAG)
# Universitas Muhammadiyah Semarang
# Universitas Wahid Hasyim Semarang
# Universitas AKI Semarang
# Akademi Statistika (AIS) Muhammadiyah Semarang
# STMIK ProVisi IT College
# AKABA 17 Agustus 1945
# STIE Dharma Putra
# Sekolah Tinggi Ilmu Ekonomi Bank BPD Jateng
# Kolese PIKA
# Sekolah Tinggi Maritim Dan Transport Amni Semarang (STIMART AMNI)
#
#
# ==== Sekolah menengah atas ====
# SMA Negeri 1 Semarang
# SMA Negeri 2 Semarang
# SMA Negeri 3 Semarang
# SMA Negeri 4 Semarang
# SMA Negeri 5 Semarang
# SMA Negeri 6 Semarang
# SMA Negeri 7 Semarang
# SMA Negeri 8 Semarang
# SMA Negeri 9 Semarang
# SMA Negeri 10 Semarang
# SMA Negeri 11 Semarang
# SMA Negeri 12 Semarang
# SMA Negeri 13 Semarang
# SMA Negeri 14 Semarang
# SMA Negeri 15 Semarang
# SMA Negeri 16 Semarang
# SMA Ibu Kartini
# SMA Budi Luhur Saint Michael
# SMA Citi School
# SMA Kolese Loyola
# SMA Karangturi
# SMA Lab School Institut Indonesia
# SMA Sedes Sapiantiae
# SMA Kebon Dalem
# SMA Kristen Terang Bangsa
# SMA Kristen Tri Tunggal
# SMA Kristen YSKI
# SMA Krista Mitra
# SMA Pangudi Luhur Don Bosco
# SMA Theresiana 1
# SMA Theresiana 2
# SMA Islam Sultan Agung 1
# SMA Islam Sultan Agung 2
# SMA Semesta
# SMA Sint Louis
# SMA Kesatrian 1
# SMA Kesatrian 2
# SMA Hidayatullah
# SMA Nasima
# SMA Mataram
#
#
# == Kota kembar ==
#  Beihai, Republik Rakyat Tiongkok
#  Fuzhou, Republik Rakyat Tiongkok
#  Brisbane, Australia
#  Da Nang, Vietnam
#  Tallahassee, Florida, Amerika Serikat
#  Kota Melaka, Malaysia
#  Tegucigalpa, Honduras
#
#
# == Lain-lain ==
# Semarang memiliki slogan sebagai Kota ATLAS (Aman, Tertib, Lancar, Asri dan Sehat).
# Beberapa pasar besar anatara lain pasar Johar, pasar Peterongan, pasar Jatingaleh, pasar Banyumanik, pasar Kobong, pasar Karangayu, pasar Bulu, pasar Gang Baru, dll.
# Perusahaan Farmasi antara lain Phapros, Saka Farma, DGPharm, dan Zenith.
# Pabrik Jamu antara lain Jamu Jago, Sido Muncul, Nyonya Meneer, Jamu Leo, dll.
# Pernah populer penggunaan bahasa pergaulan yang disebut bahasa Walikan.
#
#
# == Seniman dan selebriti ==
# Tukul Arwana, pelawak dan presenter talkshow Bukan Empat Mata di stasiun televisi Trans 7.
# Ki Joko Hadiwijoyo, dalang wayang kulit asal Kota Semarang.
# Ki Nartosabdho, dalang Wayang kulit asal Kota Semarang kelahiran Klaten yang meninggal pada tahun 1985 lalu.
# Anne Avantie, desainer kondang
# Asty Ananta, pemain sinetron dan pembawa acara
# Tia AFI, pemenang AFI indosiar
# Raden Saleh, pelukis Indonesia
# Philip ten Klooster, pematung Belanda
# Max van Egmond, penyanyi bas-bariton Belanda
# Daniel Sahuleka, penyanyi Belanda berdarah Maluku-Tionghoa-Sunda
# Nedly Andrew Girke Elstak, komponis, peniup terompet, dan pianis jazz Belanda
# Johanna Carolina van der Wal, musikus dan pianis Belanda
# Robert Maingay, pematung Belanda
# Willem Einthoven (1860–1927), dokter dan peneliti Belanda. Usaha penelitiannya mengarah kepada Elektrokardiogram (mendapatkan hadiah Nobel bidang kedokteran 1924)
# Fuad Hassan (1929–2007), politikus, Menteri Pendidikan dan Kebudayaan (1985–1993)
# Nh. Dini 1936), sastrawati
# Shania Junianatha, personel JKT48
# Muklis Sutan Rambing, pemilik dan pelatih Sasana Tinju Tugu Muda Semarang sekarang berubah Sasana Tinju Temujin Rambing di Kampung Lasipin 339A, Kota Semarang Timur.
# Anindya Kusuma Putri, Puteri Indonesia 2015.
# Clarisa Dewi, Runner Up X Factor Indonesia Season 2 Tahun 2015.
# Petrus Agung Purnomo, pemuka agama Protestan yang paling disegani di Kota Semarang dan pendiri Gereja Holy Stadium milik JKI Injil Kerajaan yang terletak di kawasan Pantai Marina Semarang
# Angie Ang, presenter berita di stasiun televisi NET.
#
#
# == Referensi ==
#
#
# == Pranala luar ==
# (Indonesia) Situs web Semarang
# Panduan Wisata Semarang

# %% [markdown]
# - Images & Links

# %%
print (page.images[0])
print (page.links[0])
print (page.categories)
# Out:
# https://upload.wikimedia.org/wikipedia/id/1/14/Semarangskyline.jpeg
# 1547
# ['Kategori:Halaman dengan argumen ganda di pemanggilan templat', 'Kategori:Halaman dengan galat skrip', 'Kategori:Ibu kota provinsi di Indonesia', 'Kategori:Kategori dengan pranala berbeda dengan Wikidata', 'Kategori:Kota Pusaka di Indonesia', 'Kategori:Kota Semarang', 'Kategori:Kota di Indonesia', 'Kategori:Kota di Jawa Tengah', 'Kategori:Pages using invalid self-closed HTML tags']

# %% [markdown]
# - Geosearch

# %%
print (wikipedia.geosearch(-6.966667, 110.41666699999996))
# Out:
# ['Stasiun Semarang Poncol']

# %% [markdown]
# ### 3. Foursquare
#
# #### a. Register app
# Lakukan register app di [sini](https://id.foursquare.com/developers/). Pastikan mendapatkan <i>Client ID</i> dan <i>Client Secret</i>
#
# #### b. Install Foursquare
# Install menggunakan <u>pip install foursquare</u>. Untuk link github bisa menuju ke [sini](https://github.com/mLewisLogic/foursquare) dan untuk dokumentasi bisa dibaca di [sini](https://developer.foursquare.com/docs/)

# %% [markdown]
# #### c. Inisialisasi
# Untuk melakukan inisialisasi, seperti biasa lakukan <b>import foursquare</b>. Pada API foursquare, untuk mengakses terdapat 2 buah cara:
# 1. Userless Access<br>
# Pada Userless Access, disini kita tidak memerlukan <b>access token</b> untuk mengakses API. Tetapi, hanya bisa mengakses API yang tanpa melibatkan <i>user</i> karena tidak melakukan user auth untuk mendapatkan <b>access token</b>. Sehingga hanya bisa mengakses API secara umum, seperti pencarian <i>venues</i>
#
# 2. Authenticated User Access<br>
# Lebih lengkap dalam mengakses API, karena sudah melakukan user auth dan mendapatkan <b>access token</b>
#
# Pada praktikum ini, menggunakan cara <b>Userless Access</b> karena nantinya disini hanya diajarkan mendapatkan review dari suatu <i>venues</i>

# %%
import foursquare

client_id = "TSILZOA3WXF2KBIF1PLMU0BGGZPUKD0RAF4NVYBDON33Z15Y"
client_secret = "OLQEWJW4X0AIERO0ZBMDAPWG5ZB1LRSW4W5NFY4CJOYQF4WS"

client = foursquare.Foursquare(client_id, client_secret)

# %% [markdown]
# - Mendapatkan detail user<br>
# Untuk mendapatkan <b>id_user</b>, terdapat pada https://id.foursquare.com/settings

# %%
client.users('361206042')
# Out:
# {'user': {'bio': '',
#   'canonicalUrl': 'https://foursquare.com/siryasirr',
#   'checkins': {'count': 5, 'items': []},
#   'contact': {},
#   'firstName': 'Yasir',
#   'friends': {'count': 0,
#    'groups': [{'count': 0,
#      'items': [],
#      'name': 'Other friends',
#      'type': 'others'}]},
#   'gender': 'male',
#   'homeCity': 'Semarang, Indonesia',
#   'id': '361206042',
#   'isAnonymous': False,
#   'lastName': 'Abdurrahman',
#   'lenses': [],
#   'lists': {'count': 2,
#    'groups': [{'count': 0, 'items': [], 'type': 'created'},
#     {'count': 0, 'items': [], 'type': 'followed'},
#     {'count': 2,
#      'items': [{'canonicalUrl': 'https://foursquare.com/siryasirr/list/todos',
#        'collaborative': False,
#        'description': '',
#        'editable': False,
#        'id': '361206042/todos',
#        'listItems': {'count': 0},
#        'name': "Yasir's Saved Places",
#        'public': True,
#        'type': 'todos',
#        'url': '/siryasirr/list/todos'},
#       {'canonicalUrl': 'https://foursquare.com/siryasirr/list/venuelikes',
#        'collaborative': False,
#        'description': '',
#        'editable': False,
#        'id': '361206042/venuelikes',
#        'listItems': {'count': 0},
#        'name': 'Yasir’s Liked Places',
#        'public': True,
#        'type': 'likes',
#        'url': '/siryasirr/list/venuelikes'}],
#      'type': 'yours'}]},
#   'mayorships': {'count': 0, 'items': []},
#   'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#    'suffix': '/361206042-TVMCNXMWZWM15KQC.jpg'},
#   'photos': {'count': 0, 'items': []},
#   'tips': {'count': 0},
#   'type': 'user'}}

# %% [markdown]
# - Mendapatkan detail dari venues<br>
# Untuk mendapatkan <b>venue id</b> bisa dilihat di url saat mengakses sebuah venue di web. Misalkan pada venue Toko Pelangi https://id.foursquare.com/v/pelangi/4c73518c376da09361e9a8c6

# %%
client.venues('40a55d80f964a52020f31ee3')
# Out:
# {'venue': {'allowMenuUrlEdit': True,
#   'attributes': {'groups': [{'count': 1,
#      'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}],
#      'name': 'Price',
#      'summary': '$$',
#      'type': 'price'},
#     {'count': 3,
#      'items': [{'displayName': 'Reservations', 'displayValue': 'Yes'}],
#      'name': 'Reservations',
#      'summary': 'Reservations',
#      'type': 'reservations'},
#     {'count': 7,
#      'items': [{'displayName': 'Credit Cards', 'displayValue': 'No'}],
#      'name': 'Credit Cards',
#      'summary': 'No Credit Cards',
#      'type': 'payments'},
#     {'count': 1,
#      'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'No'}],
#      'name': 'Outdoor Seating',
#      'type': 'outdoorSeating'},
#     {'count': 3,
#      'items': [{'displayName': 'Live Music', 'displayValue': 'Live Music'}],
#      'name': 'Music',
#      'summary': 'Live Music',
#      'type': 'music'},
#     {'count': 1,
#      'items': [{'displayName': 'Wi-Fi', 'displayValue': 'No'}],
#      'name': 'Wi-Fi',
#      'type': 'wifi'},
#     {'count': 8,
#      'items': [{'displayName': 'Breakfast', 'displayValue': 'Breakfast'},
#       {'displayName': 'Brunch', 'displayValue': 'Brunch'},
#       {'displayName': 'Lunch', 'displayValue': 'Lunch'},
#       {'displayName': 'Dinner', 'displayValue': 'Dinner'}],
#      'name': 'Menus',
#      'summary': 'Dinner, Breakfast & more',
#      'type': 'serves'},
#     {'count': 5,
#      'items': [{'displayName': 'Beer', 'displayValue': 'Beer'},
#       {'displayName': 'Wine', 'displayValue': 'Wine'}],
#      'name': 'Drinks',
#      'summary': 'Beer & Wine',
#      'type': 'drinks'},
#     {'count': 5,
#      'items': [{'displayName': 'Take-out', 'displayValue': 'Take-out'},
#       {'displayName': 'Delivery', 'displayValue': 'No Delivery'}],
#      'name': 'Dining Options',
#      'summary': 'Take-out',
#      'type': 'diningOptions'},
#     {'count': 1,
#      'items': [{'displayName': 'Coat Check', 'displayValue': 'Yes'}],
#      'name': 'Coat Check',
#      'summary': 'Coat Check',
#      'type': 'coatCheck'},
#     {'count': 1,
#      'items': [{'displayName': 'Restroom', 'displayValue': 'Yes'}],
#      'name': 'Restroom',
#      'summary': 'Restroom',
#      'type': 'restroom'},
#     {'count': 1,
#      'items': [{'displayName': 'Wheelchair Accessible',
#        'displayValue': 'Yes'}],
#      'name': 'Wheelchair Accessible',
#      'summary': 'Wheelchair Accessible',
#      'type': 'wheelchairAccessible'},
#     {'count': 1,
#      'items': [{'displayName': 'Smoking', 'displayValue': 'Yes'}],
#      'name': 'Smoking',
#      'summary': 'Smoking',
#      'type': 'smoking'}]},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'bestPhoto': {'createdAt': 1360850770,
#    'height': 612,
#    'id': '511cef52e4b00d6a2c7fddd5',
#    'prefix': 'https://irs2.4sqi.net/img/general/',
#    'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#    'suffix': '/690170_HnduV5yM9RLNUHQseOOvDi3OCm4AoYmMld79iVTxrPg.jpg',
#    'visibility': 'public',
#    'width': 612},
#   'canonicalUrl': 'https://foursquare.com/v/clinton-st-baking-co--restaurant/40a55d80f964a52020f31ee3',
#   'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#      'suffix': '.png'},
#     'id': '4bf58dd8d48988d16a941735',
#     'name': 'Bakery',
#     'pluralName': 'Bakeries',
#     'primary': True,
#     'shortName': 'Bakery'},
#    {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#      'suffix': '.png'},
#     'id': '4bf58dd8d48988d143941735',
#     'name': 'Breakfast Spot',
#     'pluralName': 'Breakfast Spots',
#     'shortName': 'Breakfast'},
#    {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#      'suffix': '.png'},
#     'id': '4bf58dd8d48988d16d941735',
#     'name': 'Café',
#     'pluralName': 'Cafés',
#     'shortName': 'Café'}],
#   'contact': {'formattedPhone': '(646) 602-6263', 'phone': '6466026263'},
#   'createdAt': 1084579200,
#   'dislike': False,
#   'hasMenu': True,
#   'hereNow': {'count': 1,
#    'groups': [{'count': 1,
#      'items': [],
#      'name': 'Other people here',
#      'type': 'others'}],
#    'summary': 'One other person is here'},
#   'hours': {'isLocalHoliday': False,
#    'isOpen': True,
#    'status': 'Open until 11:30 PM',
#    'timeframes': [{'days': 'Mon–Fri',
#      'includesToday': True,
#      'open': [{'renderedTime': '8:00 AM–4:00 PM'},
#       {'renderedTime': '6:00 PM–11:30 PM'}],
#      'segments': []},
#     {'days': 'Sat',
#      'open': [{'renderedTime': '9:00 AM–4:00 PM'},
#       {'renderedTime': '6:00 PM–11:30 PM'}],
#      'segments': []},
#     {'days': 'Sun',
#      'open': [{'renderedTime': '9:00 AM–6:00 PM'}],
#      'segments': []}]},
#   'id': '40a55d80f964a52020f31ee3',
#   'inbox': {'count': 0, 'items': []},
#   'likes': {'count': 1239,
#    'groups': [{'count': 1239, 'items': [], 'type': 'others'}],
#    'summary': '1239 Likes'},
#   'listed': {'count': 3308,
#    'groups': [{'count': 3308,
#      'items': [{'canonicalUrl': 'https://foursquare.com/citytastes/list/the-tastes-that-make-the-city-new-york-edition',
#        'collaborative': False,
#        'createdAt': 1422481788,
#        'description': "From the pastrami sandwich at Katz's to Balthazar's pomme frites, there are some dishes that are classic NYC. Foursquare's data scientists identified the top 50, and we challenge you to try them all.",
#        'editable': False,
#        'followers': {'count': 2403},
#        'guide': True,
#        'guideType': 'bestOf',
#        'id': '54c9597c498e50bd18a9d63a',
#        'listItems': {'count': 50,
#         'items': [{'createdAt': 1422481792,
#           'id': 't54c95973498e38590862bc65',
#           'photo': {'createdAt': 1432912916,
#            'height': 960,
#            'id': '55688414498eda92ec61e8e4',
#            'prefix': 'https://irs3.4sqi.net/img/general/',
#            'suffix': '/107525669_ozgo1bFRPWQkYTMnDhc8LKddeoQpctOm2KReMXASijk.jpg',
#            'user': {'firstName': 'The Tastes that Make the City',
#             'gender': 'none',
#             'id': '107525669',
#             'isAnonymous': False,
#             'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#              'suffix': '/107525669-2335RXPTBZGTCH32'}},
#            'visibility': 'public',
#            'width': 960}}]},
#        'name': 'The Tastes that Make the City: New York Edition',
#        'photo': {'createdAt': 1432912012,
#         'height': 960,
#         'id': '5568808c498eda92ec60e893',
#         'prefix': 'https://irs2.4sqi.net/img/general/',
#         'suffix': '/107525669_evsnhV04T8wpsz1MLCMupb3OwANaIIhLLeqKGkGLZU4.jpg',
#         'user': {'firstName': 'The Tastes that Make the City',
#          'gender': 'none',
#          'id': '107525669',
#          'isAnonymous': False,
#          'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#           'suffix': '/107525669-2335RXPTBZGTCH32'}},
#         'visibility': 'public',
#         'width': 720},
#        'public': True,
#        'readMoreUrl': 'https://foursquare.com/top-places/new-york-city/tastes-that-make-the-city',
#        'type': 'others',
#        'updatedAt': 1435256661,
#        'url': '/citytastes/list/the-tastes-that-make-the-city-new-york-edition',
#        'user': {'firstName': 'The Tastes that Make the City',
#         'gender': 'none',
#         'id': '107525669',
#         'isAnonymous': False,
#         'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#          'suffix': '/107525669-2335RXPTBZGTCH32'}}},
#       {'canonicalUrl': 'https://foursquare.com/michelinguides/list/2013-nyc-bib-gourmands',
#        'collaborative': False,
#        'createdAt': 1329494043,
#        'description': 'The MICHELIN Guide New York City 2013 released its largest list ever of New York City’s Bib Gourmands—establishments that serve two courses and a glass of wine or dessert for $40 or less.',
#        'editable': False,
#        'followers': {'count': 1897},
#        'id': '4f3e781be4b0500b6866c439',
#        'listItems': {'count': 127,
#         'items': [{'createdAt': 1329495849,
#           'id': 'v40a55d80f964a52020f31ee3'}]},
#        'logView': True,
#        'name': '2013 NYC Bib Gourmands',
#        'public': True,
#        'type': 'others',
#        'updatedAt': 1365970876,
#        'url': '/michelinguides/list/2013-nyc-bib-gourmands',
#        'user': {'firstName': 'Michelin Travel & Lifestyle',
#         'gender': 'none',
#         'id': '3358242',
#         'isAnonymous': False,
#         'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#          'suffix': '/VK0PPDE3V1HU20D5.jpg'},
#         'type': 'page'}},
#       {'canonicalUrl': 'https://foursquare.com/noah_weiss/list/nyc-brunch',
#        'collaborative': False,
#        'createdAt': 1306457809,
#        'description': 'Warning: waits may be long.  If looking for a reservations, just go to Five Points or Locanda Verde.',
#        'editable': False,
#        'followers': {'count': 1355},
#        'id': '4ddef6d11fc79ef4589b5dc3',
#        'listItems': {'count': 60,
#         'items': [{'createdAt': 1306457809,
#           'id': 't4a7a511970c603bbd64e8eb4',
#           'photo': {'createdAt': 1298049900,
#            'height': 537,
#            'id': '4d5eab6c7b72a34010f55dda',
#            'prefix': 'https://irs0.4sqi.net/img/general/',
#            'suffix': '/FWQ2C34ZB2FAWEPCMGBJAQRT4FZHGQ0V2H2ZTJB4ZVFBXGJN.jpg',
#            'user': {'firstName': 'G',
#             'gender': 'male',
#             'id': '6342967',
#             'isAnonymous': False,
#             'lastName': 'L',
#             'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#              'suffix': '/Q1UGJ1ZW0QNESZCN.jpg'}},
#            'visibility': 'public',
#            'width': 720}}]},
#        'name': 'NYC Brunch',
#        'photo': {'createdAt': 1297542756,
#         'height': 720,
#         'id': '4d56ee64a70c2da1895790fc',
#         'prefix': 'https://irs3.4sqi.net/img/general/',
#         'suffix': '/XCYFEROAQ0KPRWGCJYARCWBEBPV44Z0XPRNBZ5NPXEKEGXQK.jpg',
#         'user': {'firstName': 'Noah',
#          'gender': 'male',
#          'id': '697943',
#          'isAnonymous': False,
#          'lastName': 'Weiss',
#          'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#           'suffix': '/13OQO12M5VBZWAXV.png'}},
#         'visibility': 'public',
#         'width': 540},
#        'public': True,
#        'type': 'others',
#        'updatedAt': 1412604794,
#        'url': '/noah_weiss/list/nyc-brunch',
#        'user': {'firstName': 'Noah',
#         'gender': 'male',
#         'id': '697943',
#         'isAnonymous': False,
#         'lastName': 'Weiss',
#         'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#          'suffix': '/13OQO12M5VBZWAXV.png'}}},
#       {'canonicalUrl': 'https://foursquare.com/thrillist/list/thrillists-best-day-of-your-life-new-york',
#        'collaborative': False,
#        'createdAt': 1371154433,
#        'description': 'Spend every daylight hour hitting the very best restaurants, bars, patios, and more in New York, New York!',
#        'editable': False,
#        'followers': {'count': 1613},
#        'id': '51ba2801498e64775891ddf1',
#        'listItems': {'count': 10,
#         'items': [{'createdAt': 1371154497,
#           'id': 't51b71b4a498e52a93f4ca85b',
#           'photo': {'createdAt': 1370954571,
#            'height': 800,
#            'id': '51b71b4b454a536bf0d3226c',
#            'prefix': 'https://irs2.4sqi.net/img/general/',
#            'suffix': '/268135_jydIzssg4xjaFE-aX42H8KKoUARrRgFe02yco-lZvO8.jpg',
#            'user': {'firstName': 'Thrillist',
#             'gender': 'none',
#             'id': '268135',
#             'isAnonymous': False,
#             'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#              'suffix': '/EAJSSAI10XFPJI2X.jpg'},
#             'type': 'page'},
#            'visibility': 'public',
#            'width': 600}}]},
#        'logView': True,
#        'name': "Thrillist's Best Day of Your Life: New York",
#        'photo': {'createdAt': 1371187726,
#         'height': 305,
#         'id': '51baaa0e5019b691f4f28b36',
#         'prefix': 'https://irs1.4sqi.net/img/general/',
#         'suffix': '/268135_EFFW5_Nt_GETOb9PWXMMVMTxu04FVZfyRLqseGB7iNw.png',
#         'user': {'firstName': 'Thrillist',
#          'gender': 'none',
#          'id': '268135',
#          'isAnonymous': False,
#          'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#           'suffix': '/EAJSSAI10XFPJI2X.jpg'},
#          'type': 'page'},
#         'visibility': 'public',
#         'width': 298},
#        'public': True,
#        'type': 'others',
#        'updatedAt': 1400332871,
#        'url': '/thrillist/list/thrillists-best-day-of-your-life-new-york',
#        'user': {'firstName': 'Thrillist',
#         'gender': 'none',
#         'id': '268135',
#         'isAnonymous': False,
#         'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#          'suffix': '/EAJSSAI10XFPJI2X.jpg'},
#         'type': 'page'}}],
#      'name': 'Lists from other people',
#      'type': 'others'}]},
#   'location': {'address': '4 Clinton St',
#    'cc': 'US',
#    'city': 'New York',
#    'country': 'United States',
#    'crossStreet': 'at E Houston St',
#    'formattedAddress': ['4 Clinton St (at E Houston St)',
#     'New York, NY 10002',
#     'United States'],
#    'lat': 40.721326234744836,
#    'lng': -73.98397571726198,
#    'postalCode': '10002',
#    'state': 'NY'},
#   'menu': {'anchor': 'View Menu',
#    'label': 'Menu',
#    'mobileUrl': 'https://foursquare.com/v/40a55d80f964a52020f31ee3/device_menu',
#    'type': 'Menu',
#    'url': 'https://foursquare.com/v/clinton-st-baking-co--restaurant/40a55d80f964a52020f31ee3/menu'},
#   'name': 'Clinton St. Baking Co. & Restaurant',
#   'ok': False,
#   'page': {'user': {'bio': '',
#     'contact': {},
#     'firstName': 'Clinton St. Baking Co. & Restaurant',
#     'gender': 'none',
#     'homeCity': 'New York, NY',
#     'id': '219374397',
#     'isAnonymous': False,
#     'lists': {'groups': [{'count': 2, 'items': [], 'type': 'created'}]},
#     'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#      'suffix': '/219374397-KSIJPSEVEN43EJJM.png'},
#     'tips': {'count': 0},
#     'type': 'venuePage',
#     'venue': {'id': '40a55d80f964a52020f31ee3'}}},
#   'pageUpdates': {'count': 1, 'items': []},
#   'photos': {'count': 1699,
#    'groups': [{'count': 1699,
#      'items': [{'createdAt': 1360850770,
#        'height': 612,
#        'id': '511cef52e4b00d6a2c7fddd5',
#        'prefix': 'https://irs2.4sqi.net/img/general/',
#        'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#        'suffix': '/690170_HnduV5yM9RLNUHQseOOvDi3OCm4AoYmMld79iVTxrPg.jpg',
#        'user': {'firstName': 'caroline',
#         'gender': 'female',
#         'id': '690170',
#         'isAnonymous': False,
#         'lastName': 'cahill',
#         'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#          'suffix': '/F5IKVUEOIEXEJN2E.png'}},
#        'visibility': 'public',
#        'width': 612},
#       {'createdAt': 1369241785,
#        'height': 720,
#        'id': '519cf8b9498eec8281f3d628',
#        'prefix': 'https://irs3.4sqi.net/img/general/',
#        'source': {'name': 'Foursquare for iOS',
#         'url': 'https://foursquare.com/download/#/iphone'},
#        'suffix': '/16255228_duwLLI2jD8n3Wmy-3WjDr9aO92nNZugYEqbGU6N9yZc.jpg',
#        'user': {'firstName': 'Jin',
#         'gender': 'female',
#         'id': '16255228',
#         'isAnonymous': False,
#         'lastName': 'Chen',
#         'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#          'suffix': '/G3FKYQP4PKBVDTJH.jpg'}},
#        'visibility': 'public',
#        'width': 720},
#       {'createdAt': 1338571566,
#        'height': 612,
#        'id': '4fc8fb2ee4b032a1869151a1',
#        'prefix': 'https://irs2.4sqi.net/img/general/',
#        'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#        'suffix': '/yVXkbnoKnheJ79EOHzAgwymmeCWBJ9OMGi5JKAJCf1c.jpg',
#        'user': {'firstName': 'Alexis',
#         'gender': 'female',
#         'id': '1160165',
#         'isAnonymous': False,
#         'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#          'suffix': '/O1KYHFA54LHVAUNW.jpg'}},
#        'visibility': 'public',
#        'width': 612},
#       {'createdAt': 1349530894,
#        'height': 540,
#        'id': '5070350ee4b0cc0ec0c6a39a',
#        'prefix': 'https://irs3.4sqi.net/img/general/',
#        'source': {'name': 'Foursquare for iOS',
#         'url': 'https://foursquare.com/download/#/iphone'},
#        'suffix': '/3390515_w8eOS632OrJOFw6EPGq3udukOvWSmbzf5sXBUqEMeXc.jpg',
#        'user': {'firstName': 'Jisun',
#         'gender': 'female',
#         'id': '3390515',
#         'isAnonymous': False,
#         'lastName': 'Kim',
#         'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#          'suffix': '/V5IWOCJLUHMOPYPQ.jpg'}},
#        'visibility': 'public',
#        'width': 720},
#       {'createdAt': 1336395691,
#        'height': 540,
#        'id': '4fa7c7abe4b0f90209111ab9',
#        'prefix': 'https://irs2.4sqi.net/img/general/',
#        'source': {'name': 'Foursquare for iOS',
#         'url': 'https://foursquare.com/download/#/iphone'},
#        'suffix': '/8qk_HIG-lTK4UaKu42k-4IMk1Wv-lgj-crBv5SgnrwE.jpg',
#        'user': {'firstName': 'Ann',
#         'gender': 'female',
#         'id': '1505016',
#         'isAnonymous': False,
#         'lastName': 'Long',
#         'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#          'suffix': '/1505016-YWZ1IBR15BPCXSDJ.jpg'}},
#        'visibility': 'public',
#        'width': 720},
#       {'createdAt': 1359916347,
#        'height': 960,
#        'id': '510ead3be4b0ab88a76abd22',
#        'prefix': 'https://irs0.4sqi.net/img/general/',
#        'source': {'name': 'Foursquare for iOS',
#         'url': 'https://foursquare.com/download/#/iphone'},
#        'suffix': '/42993070_LOIjZpHMl6Ihea4V6RCG0vB3AadT5edfKFHTXg5v6Kk.jpg',
#        'user': {'firstName': 'Nazly',
#         'gender': 'female',
#         'id': '42993070',
#         'isAnonymous': False,
#         'lastName': 'Hafez',
#         'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#          'suffix': '/OM0AHEQXWSWCSLNJ.jpg'}},
#        'visibility': 'public',
#        'width': 720}],
#      'name': 'Venue photos',
#      'type': 'venue'}]},
#   'phrases': [{'count': 122,
#     'phrase': 'blueberry pancakes',
#     'sample': {'entities': [{'indices': [25, 43], 'type': 'keyPhrase'}],
#      'text': '... cured bacon, and the blueberry pancakes are the best!'}},
#    {'count': 36,
#     'phrase': 'sugar cured bacon',
#     'sample': {'entities': [{'indices': [4, 21], 'type': 'keyPhrase'}],
#      'text': "The sugar cured bacon. The raspberry jam. Eat them. You'll be so..."}},
#    {'count': 27,
#     'phrase': 'maple butter',
#     'sample': {'entities': [{'indices': [23, 35], 'type': 'keyPhrase'}],
#      'text': '... pancakes with warm maple butter are amazing! Oh & the sugar cured bacon is...'}}],
#   'popular': {'isLocalHoliday': False,
#    'isOpen': False,
#    'timeframes': [{'days': 'Today',
#      'includesToday': True,
#      'open': [{'renderedTime': '8:00 AM–2:00 PM'},
#       {'renderedTime': '6:00 PM–9:00 PM'}],
#      'segments': []},
#     {'days': 'Thu',
#      'open': [{'renderedTime': '8:00 AM–3:00 PM'},
#       {'renderedTime': '6:00 PM–9:00 PM'}],
#      'segments': []},
#     {'days': 'Fri',
#      'open': [{'renderedTime': '8:00 AM–3:00 PM'},
#       {'renderedTime': '6:00 PM–10:00 PM'}],
#      'segments': []},
#     {'days': 'Sat',
#      'open': [{'renderedTime': '8:00 AM–4:00 PM'},
#       {'renderedTime': '7:00 PM–10:00 PM'}],
#      'segments': []},
#     {'days': 'Sun',
#      'open': [{'renderedTime': '8:00 AM–5:00 PM'}],
#      'segments': []},
#     {'days': 'Mon',
#      'open': [{'renderedTime': '8:00 AM–3:00 PM'},
#       {'renderedTime': '6:00 PM–9:00 PM'}],
#      'segments': []},
#     {'days': 'Tue',
#      'open': [{'renderedTime': '8:00 AM–2:00 PM'},
#       {'renderedTime': '7:00 PM–9:00 PM'}],
#      'segments': []}]},
#   'price': {'currency': '$', 'message': 'Moderate', 'tier': 2},
#   'rating': 9.1,
#   'ratingColor': '00B551',
#   'ratingSignals': 1885,
#   'reasons': {'count': 1,
#    'items': [{'reasonName': 'rawLikesReason',
#      'summary': 'Lots of people like this place',
#      'type': 'general'}]},
#   'shortUrl': 'http://4sq.com/1UrXyu',
#   'specials': {'count': 0, 'items': []},
#   'stats': {'checkinsCount': 22799,
#    'tipCount': 728,
#    'usersCount': 20604,
#    'visitsCount': 29890},
#   'tags': ['bakery',
#    'baking',
#    'breakfast',
#    'brunch',
#    'fried chicken',
#    'pancakes',
#    'scones',
#    'southern'],
#   'timeZone': 'America/New_York',
#   'tips': {'count': 728,
#    'groups': [{'count': 728,
#      'items': [{'agreeCount': 67,
#        'canonicalUrl': 'https://foursquare.com/item/51b71b4a498e52a93f4ca85b',
#        'createdAt': 1370954570,
#        'disagreeCount': 0,
#        'id': '51b71b4a498e52a93f4ca85b',
#        'lang': 'en',
#        'likes': {'count': 67,
#         'groups': [{'count': 67, 'items': [], 'type': 'others'}],
#         'summary': '67 likes'},
#        'logView': True,
#        'photo': {'createdAt': 1370954571,
#         'height': 800,
#         'id': '51b71b4b454a536bf0d3226c',
#         'prefix': 'https://irs2.4sqi.net/img/general/',
#         'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'},
#         'suffix': '/268135_jydIzssg4xjaFE-aX42H8KKoUARrRgFe02yco-lZvO8.jpg',
#         'visibility': 'public',
#         'width': 600},
#        'photourl': 'https://irs2.4sqi.net/img/general/original/268135_jydIzssg4xjaFE-aX42H8KKoUARrRgFe02yco-lZvO8.jpg',
#        'text': 'Pancakes that are worth the five-hour wait on a Saturday, but if you go during the week you just might beat the crowd...',
#        'todo': {'count': 86},
#        'type': 'user',
#        'user': {'firstName': 'Thrillist',
#         'gender': 'none',
#         'id': '268135',
#         'isAnonymous': False,
#         'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#          'suffix': '/EAJSSAI10XFPJI2X.jpg'},
#         'type': 'page'}},
#       {'agreeCount': 19,
#        'canonicalUrl': 'https://foursquare.com/item/4a7a511970c603bbd64e8eb4',
#        'createdAt': 1249530137,
#        'disagreeCount': 0,
#        'id': '4a7a511970c603bbd64e8eb4',
#        'lang': 'en',
#        'likes': {'count': 18,
#         'groups': [{'count': 18, 'items': [], 'type': 'others'}],
#         'summary': '18 likes'},
#        'logView': True,
#        'text': "I don't care if you get the beloved blueberry pancakes or not, but the must have here is the SUGAR-CURED BACON!",
#        'todo': {'count': 51},
#        'type': 'user',
#        'user': {'firstName': 'Nina',
#         'gender': 'female',
#         'id': '27078',
#         'isAnonymous': False,
#         'lastName': 'C',
#         'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#          'suffix': '/YI54VKYBE1H0QZ00.jpg'}}},
#       {'agreeCount': 5,
#        'canonicalUrl': 'https://foursquare.com/item/49bec7da70c603bb5c128eb4',
#        'createdAt': 1237239770,
#        'disagreeCount': 0,
#        'id': '49bec7da70c603bb5c128eb4',
#        'lang': 'en',
#        'likes': {'count': 15,
#         'groups': [{'count': 15, 'items': [], 'type': 'others'}],
#         'summary': '15 likes'},
#        'logView': True,
#        'text': 'Go to Clinton Street Baking Co. for dinner and order the blueberry pancakes. No line!',
#        'todo': {'count': 5},
#        'type': 'user',
#        'user': {'firstName': 'Kathryn',
#         'gender': 'female',
#         'id': '1357',
#         'isAnonymous': False,
#         'lastName': 'Yu',
#         'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#          'suffix': '/1357-TSY0DTLTJQ5C3BYM'}}},
#       {'agreeCount': 13,
#        'canonicalUrl': 'https://foursquare.com/item/50e774a4e4b0d05a55aaae01',
#        'createdAt': 1357345956,
#        'disagreeCount': 0,
#        'id': '50e774a4e4b0d05a55aaae01',
#        'lang': 'en',
#        'likes': {'count': 13,
#         'groups': [{'count': 13, 'items': [], 'type': 'others'}],
#         'summary': '13 likes'},
#        'logView': True,
#        'text': 'The tip list on foursquare is longer than the wait. You might finish reading by the time a table opens up!',
#        'todo': {'count': 1},
#        'type': 'user',
#        'user': {'firstName': 'Pierce',
#         'gender': 'male',
#         'id': '15524627',
#         'isAnonymous': False,
#         'lastName': 'Pierson',
#         'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#          'suffix': '/FTD4P53AMYR1HLJW.jpg'}}},
#       {'agreeCount': 12,
#        'authorInteractionType': 'liked',
#        'canonicalUrl': 'https://foursquare.com/item/538242f2498ea6186c5a95e4',
#        'createdAt': 1401045746,
#        'disagreeCount': 0,
#        'id': '538242f2498ea6186c5a95e4',
#        'lang': 'en',
#        'likes': {'count': 12,
#         'groups': [{'count': 12, 'items': [], 'type': 'others'}],
#         'summary': '12 likes'},
#        'logView': True,
#        'photo': {'createdAt': 1428359075,
#         'height': 1920,
#         'id': '552307a3498e258d657e0203',
#         'prefix': 'https://irs3.4sqi.net/img/general/',
#         'source': {'name': 'Foursquare for iOS',
#          'url': 'http://developer.foursquare.com'},
#         'suffix': '/19755935_-l-h-UIl6NzZzkTumZjTx4Cg9n7d-U7ox50hUAVgnnI.jpg',
#         'visibility': 'public',
#         'width': 1440},
#        'photourl': 'https://irs3.4sqi.net/img/general/original/19755935_-l-h-UIl6NzZzkTumZjTx4Cg9n7d-U7ox50hUAVgnnI.jpg',
#        'text': 'Fucking sugar cured bacon. Fuck.',
#        'todo': {'count': 1},
#        'type': 'user',
#        'user': {'firstName': 'Jack',
#         'gender': 'male',
#         'id': '19755935',
#         'isAnonymous': False,
#         'lastName': 'Osborne',
#         'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#          'suffix': '/00AZPGHUXD1R22MO.jpg'}}},
#       {'agreeCount': 11,
#        'canonicalUrl': 'https://foursquare.com/item/52fd5170498e2b04bc9b659f',
#        'createdAt': 1392333168,
#        'disagreeCount': 0,
#        'id': '52fd5170498e2b04bc9b659f',
#        'lang': 'en',
#        'likes': {'count': 12,
#         'groups': [{'count': 12, 'items': [], 'type': 'others'}],
#         'summary': '12 likes'},
#        'logView': True,
#        'photo': {'createdAt': 1392333839,
#         'height': 567,
#         'id': '52fd540f11d2e24485235588',
#         'prefix': 'https://irs0.4sqi.net/img/general/',
#         'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'},
#         'suffix': '/268135_zgHDCPyJZdgrBuCVaDjGTisShvEiu9S54enRcKEljEg.png',
#         'visibility': 'public',
#         'width': 755},
#        'photourl': 'https://irs0.4sqi.net/img/general/original/268135_zgHDCPyJZdgrBuCVaDjGTisShvEiu9S54enRcKEljEg.png',
#        'text': "It's Pancake Month so there's a different specialty pancake every few days (from 8am-4pm and 6-11pm), including one with raspberries and raspberry-caramel sauce tomorrow. Only available on weekdays.",
#        'todo': {'count': 6},
#        'type': 'user',
#        'url': 'http://www.thrillist.com/entertainment/new-york/things-to-do-this-weekend-february-13-16?utm_source=foursquare&utm_medium=social&utm_campaign=thrillist',
#        'user': {'firstName': 'Thrillist',
#         'gender': 'none',
#         'id': '268135',
#         'isAnonymous': False,
#         'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#          'suffix': '/EAJSSAI10XFPJI2X.jpg'},
#         'type': 'page'}},
#       {'agreeCount': 12,
#        'canonicalUrl': 'https://foursquare.com/item/4d0250a0e14d59416b700494',
#        'createdAt': 1291997344,
#        'disagreeCount': 0,
#        'id': '4d0250a0e14d59416b700494',
#        'lang': 'en',
#        'likes': {'count': 12,
#         'groups': [{'count': 12, 'items': [], 'type': 'others'}],
#         'summary': '12 likes'},
#        'logView': True,
#        'text': 'Avoid two-hour brunch lines by ordering the stack of blueberry pancakes for dinner.',
#        'todo': {'count': 20},
#        'type': 'user',
#        'url': 'http://dailycandy.com/new-york/article/90341/Clinton-Street-Baking-Cos-Brookies',
#        'user': {'firstName': 'DailyCandy',
#         'gender': 'none',
#         'id': '3107021',
#         'isAnonymous': False,
#         'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#          'suffix': '/YQTLAT4SMBM3W5KF.png'},
#         'type': 'page'}},
#       {'agreeCount': 12,
#        'canonicalUrl': 'https://foursquare.com/item/4ac11cae70c603bb09868eb4',
#        'createdAt': 1254169774,
#        'disagreeCount': 0,
#        'id': '4ac11cae70c603bb09868eb4',
#        'lang': 'en',
#        'likes': {'count': 12,
#         'groups': [{'count': 12, 'items': [], 'type': 'others'}],
#         'summary': '12 likes'},
#        'logView': True,
#        'text': 'Maple butter that comes with french toast & pancakes will make you feel feelings.',
#        'todo': {'count': 4},
#        'type': 'user',
#        'user': {'firstName': 'Emily',
#         'gender': 'female',
#         'id': '19811',
#         'isAnonymous': False,
#         'lastName': 'Vernon',
#         'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#          'suffix': '/19811-DFZ0AT12NF3NLJ1R'}}},
#       {'agreeCount': 11,
#        'canonicalUrl': 'https://foursquare.com/item/4eb01cb30cd6528d834a9d05',
#        'createdAt': 1320164531,
#        'disagreeCount': 0,
#        'id': '4eb01cb30cd6528d834a9d05',
#        'lang': 'en',
#        'likes': {'count': 11,
#         'groups': [{'count': 11, 'items': [], 'type': 'others'}],
#         'summary': '11 likes'},
#        'logView': True,
#        'text': "You'll likely have to wait a while to get a seat here around brunch time so when you do sit down, don't leave without getting their unbelievable blueberry pancakes and sugar cured bacon!",
#        'todo': {'count': 4},
#        'type': 'user',
#        'user': {'firstName': 'New York Habitat',
#         'gender': 'none',
#         'id': '13889528',
#         'isAnonymous': False,
#         'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#          'suffix': '/PGPPIGGHW44SEI4X.jpg'},
#         'type': 'chain'}},
#       {'agreeCount': 10,
#        'canonicalUrl': 'https://foursquare.com/item/4ceb5283fe90a35d44a7520e',
#        'createdAt': 1290490499,
#        'disagreeCount': 0,
#        'id': '4ceb5283fe90a35d44a7520e',
#        'lang': 'en',
#        'likes': {'count': 10,
#         'groups': [{'count': 10, 'items': [], 'type': 'others'}],
#         'summary': '10 likes'},
#        'logView': True,
#        'text': 'Try the Blueberry Pancakes',
#        'todo': {'count': 4},
#        'type': 'user',
#        'user': {'firstName': 'Foodspotting',
#         'gender': 'none',
#         'id': '4563783',
#         'isAnonymous': False,
#         'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#          'suffix': '/QRRYD2IOXN3KTHZP.png'}}},
#       {'agreeCount': 2,
#        'canonicalUrl': 'https://foursquare.com/item/4cb1fa69ef1b37047ca04700',
#        'createdAt': 1286732393,
#        'disagreeCount': 0,
#        'id': '4cb1fa69ef1b37047ca04700',
#        'lang': 'en',
#        'likes': {'count': 9,
#         'groups': [{'count': 9,
#           'items': [{'firstName': 'David',
#             'gender': 'male',
#             'id': '6658213',
#             'isAnonymous': False,
#             'lastName': 'Zhang',
#             'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#              'suffix': '/6658213-NPKIXC545J1GXYRY.jpg'}},
#            {'firstName': 'Alejandra',
#             'gender': 'female',
#             'id': '49050780',
#             'isAnonymous': False,
#             'lastName': 'Galvan',
#             'photo': {'default': True,
#              'prefix': 'https://irs2.4sqi.net/img/user/',
#              'suffix': '/blank_girl.png'}}],
#           'type': 'others'}],
#         'summary': '9 likes'},
#        'logView': True,
#        'text': "don't leave without tryig the sugar cured bacon!",
#        'todo': {'count': 4},
#        'type': 'user',
#        'user': {'firstName': 'Teresa',
#         'gender': 'female',
#         'id': '16598',
#         'isAnonymous': False,
#         'lastName': 'W',
#         'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#          'suffix': '/J3PGVZPY23WC4VDS.png'}}},
#       {'agreeCount': 9,
#        'canonicalUrl': 'https://foursquare.com/item/4c81aeb3309aef3b0063be81',
#        'createdAt': 1283567283,
#        'disagreeCount': 0,
#        'id': '4c81aeb3309aef3b0063be81',
#        'lang': 'en',
#        'likes': {'count': 9,
#         'groups': [{'count': 9,
#           'items': [{'firstName': 'Brunold',
#             'gender': 'male',
#             'id': '149405',
#             'isAnonymous': False,
#             'lastName': 'Loidl',
#             'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#              'suffix': '/149405-5UP3W0AUI50ZCDMH.jpg'}},
#            {'firstName': 'Tatiana',
#             'gender': 'female',
#             'id': '36065546',
#             'isAnonymous': False,
#             'lastName': 'Margarido',
#             'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#              'suffix': '/D0VY32NDVGI1NGQ4.jpg'}},
#            {'firstName': 'Natalia',
#             'gender': 'female',
#             'id': '9042948',
#             'isAnonymous': False,
#             'lastName': 'Fava',
#             'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#              'suffix': '/9042948-BKRYLVNYYWVRZF2S.jpg'}},
#            {'firstName': 'Dejay',
#             'gender': 'male',
#             'id': '20398258',
#             'isAnonymous': False,
#             'lastName': 'R',
#             'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#              'suffix': '/20398258-4T3IPCCRVXCLU2GN.jpg'}}],
#           'type': 'others'}],
#         'summary': '9 likes'},
#        'logView': True,
#        'photo': {'createdAt': 1374256149,
#         'height': 640,
#         'id': '51e97c15ccda0e9f6c84aef2',
#         'prefix': 'https://irs1.4sqi.net/img/general/',
#         'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'},
#         'suffix': '/95423_TkslitX7GoBro27vnoIeBl3Ne265oXLkwyAr9P6aSiw.jpg',
#         'visibility': 'public',
#         'width': 480},
#        'photourl': 'https://irs1.4sqi.net/img/general/original/95423_TkslitX7GoBro27vnoIeBl3Ne265oXLkwyAr9P6aSiw.jpg',
#        'text': 'Could this be the best brunch in NYC?  Expect a long, but worth it, wait.  Then devour an order of the Pear Waffles – a seasonal special!',
#        'todo': {'count': 22},
#        'type': 'user',
#        'user': {'firstName': 'The Corcoran Group',
#         'gender': 'none',
#         'id': '95423',
#         'isAnonymous': False,
#         'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#          'suffix': '/95423-FGRZ1IMU5FZQMCZB.jpg'},
#         'type': 'page'}},
#       {'agreeCount': 8,
#        'canonicalUrl': 'https://foursquare.com/item/50e5d167e4b053f1ce9b8bef',
#        'createdAt': 1357238631,
#        'disagreeCount': 0,
#        'id': '50e5d167e4b053f1ce9b8bef',
#        'lang': 'en',
#        'likes': {'count': 8,
#         'groups': [{'count': 8,
#           'items': [{'firstName': 'Betty',
#             'gender': 'female',
#             'id': '151262490',
#             'isAnonymous': False,
#             'lastName': 'Wang',
#             'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#              'suffix': '/151262490-4X5YALU3RA43JBQS.jpg'}},
#            {'firstName': 'Helio',
#             'gender': 'male',
#             'id': '63127677',
#             'isAnonymous': False,
#             'lastName': 'Menoscal Calderon',
#             'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#              'suffix': '/1CP32Q0WBA0W122L.jpg'}},
#            {'firstName': 'Aleena',
#             'gender': 'female',
#             'id': '168595',
#             'isAnonymous': False,
#             'lastName': 'Wee',
#             'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#              'suffix': '/KYS0AL1GWM5GNG40.jpg'}},
#            {'firstName': 'Thomas',
#             'gender': 'male',
#             'id': '421931',
#             'isAnonymous': False,
#             'lastName': 'Rix',
#             'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#              'suffix': '/421931-OXDV0ERQLWNFVPQO.jpg'}}],
#           'type': 'others'}],
#         'summary': '8 likes'},
#        'logView': True,
#        'text': 'Come by yo damn self to be seated with ease at the bar and be served in 5 minutes flat. Leave all friends and cohorts at their respective homes or cubicles.',
#        'todo': {'count': 2},
#        'type': 'user',
#        'user': {'firstName': 'Tyger',
#         'gender': 'female',
#         'id': '9320315',
#         'isAnonymous': False,
#         'lastName': 'Madenda',
#         'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#          'suffix': '/YBSGKA1CPOM2LP5Q.jpg'}}},
#       {'agreeCount': 9,
#        'canonicalUrl': 'https://foursquare.com/item/53acbd2f498e49c04f566ccf',
#        'createdAt': 1403829551,
#        'disagreeCount': 0,
#        'id': '53acbd2f498e49c04f566ccf',
#        'lang': 'en',
#        'lastUpvoteTimestamp': 1478282346,
#        'lastVoteText': 'Upvoted 5 days ago',
#        'likes': {'count': 7,
#         'groups': [{'count': 7,
#           'items': [{'firstName': 'Victor',
#             'gender': 'male',
#             'id': '135364446',
#             'isAnonymous': False,
#             'lastName': 'Chen',
#             'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#              'suffix': '/135364446-NRZERKDO2OSFQ1S0.jpg'}},
#            {'firstName': 'Constantine',
#             'gender': 'male',
#             'id': '8492207',
#             'isAnonymous': False,
#             'lastName': 'Antonakos',
#             'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#              'suffix': '/8492207-WU54KCJUJYN0XI22.jpg'}},
#            {'firstName': 'Catherine',
#             'gender': 'female',
#             'id': '82819351',
#             'isAnonymous': False,
#             'lastName': 'Quintiliani',
#             'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#              'suffix': '/82819351-2WS0H5UEG5SCL251.jpg'}},
#            {'firstName': 'Jessica',
#             'gender': 'female',
#             'id': '9609125',
#             'isAnonymous': False,
#             'lastName': 'Webster',
#             'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#              'suffix': '/R4N5E4G04AUJHRMV.jpg'}}],
#           'type': 'others'}],
#         'summary': '7 likes'},
#        'logView': True,
#        'photo': {'createdAt': 1403829551,
#         'height': 960,
#         'id': '53acbd2f498ec0c8e72aec4b',
#         'prefix': 'https://irs1.4sqi.net/img/general/',
#         'source': {'name': 'Foursquare for iOS',
#          'url': 'http://developer.foursquare.com'},
#         'suffix': '/32_A3AgTjFJk133VmTufz__v17vThaQdT6JEB-et7yZmIo.jpg',
#         'visibility': 'public',
#         'width': 720},
#        'photourl': 'https://irs1.4sqi.net/img/general/original/32_A3AgTjFJk133VmTufz__v17vThaQdT6JEB-et7yZmIo.jpg',
#        'text': "Sweet mother of Baby Jesus, the fried chicken & waffles is everything it's cracked up to be. Don't fear the sweet honey syrup -- put it on the chicken!",
#        'todo': {'count': 3},
#        'type': 'user',
#        'user': {'firstName': 'Dens',
#         'gender': 'male',
#         'id': '32',
#         'isAnonymous': False,
#         'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#          'suffix': '/32_1239135232.jpg'}}},
#       {'agreeCount': 6,
#        'canonicalUrl': 'https://foursquare.com/item/54c95973498e38590862bc65',
#        'createdAt': 1422481779,
#        'disagreeCount': 0,
#        'editedAt': 1424718368,
#        'id': '54c95973498e38590862bc65',
#        'lang': 'en',
#        'likes': {'count': 6,
#         'groups': [{'count': 6,
#           'items': [{'firstName': 'Noor',
#             'gender': 'none',
#             'id': '167139339',
#             'isAnonymous': False,
#             'lastName': 'ES',
#             'photo': {'default': True,
#              'prefix': 'https://irs0.4sqi.net/img/user/',
#              'suffix': '/blank_boy.png'}},
#            {'firstName': 'Jessica',
#             'gender': 'female',
#             'id': '50735008',
#             'isAnonymous': False,
#             'lastName': 'Lin',
#             'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#              'suffix': '/50735008-V4VA51KCI2CLFHY1.jpg'}},
#            {'firstName': 'Jacob',
#             'gender': 'male',
#             'id': '117149858',
#             'isAnonymous': False,
#             'lastName': 'Forster',
#             'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#              'suffix': '/117149858-WIAQOTCAZ22UBN4W.jpg'}},
#            {'firstName': 'Kelsey',
#             'gender': 'female',
#             'id': '23408981',
#             'isAnonymous': False,
#             'lastName': 'L',
#             'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#              'suffix': '/23408981-CV4ON02JBV5O5G4T.jpg'}}],
#           'type': 'others'}],
#         'summary': '6 likes'},
#        'logView': True,
#        'text': 'The blueberry pancakes are the best pancakes in NYC, making our list of "The Tastes That Make the City: NYC Edition."',
#        'todo': {'count': 78},
#        'type': 'user',
#        'url': 'https://foursquare.com/top-places/new-york-city/tastes-that-make-the-city',
#        'user': {'firstName': 'The Tastes that Make the City',
#         'gender': 'none',
#         'id': '107525669',
#         'isAnonymous': False,
#         'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#          'suffix': '/107525669-2335RXPTBZGTCH32'}}},
#       {'agreeCount': 6,
#        'canonicalUrl': 'https://foursquare.com/item/51550c6ce4b0370d656c8800',
#        'createdAt': 1364528236,
#        'disagreeCount': 0,
#        'id': '51550c6ce4b0370d656c8800',
#        'lang': 'en',
#        'likes': {'count': 6,
#         'groups': [{'count': 6,
#           'items': [{'firstName': 'Michelle',
#             'gender': 'female',
#             'id': '95582424',
#             'isAnonymous': False,
#             'lastName': 'Deng',
#             'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#              'suffix': '/95582424-DWDZNKFZZ03ZLOCM.jpg'}},
#            {'firstName': 'Mashka',
#             'gender': 'female',
#             'id': '3948443',
#             'isAnonymous': False,
#             'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#              'suffix': '/BRUBISRJ1LVCC3CJ.jpg'}},
#            {'firstName': 'Jasmine',
#             'gender': 'female',
#             'id': '1184206',
#             'isAnonymous': False,
#             'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#              'suffix': '/1184206-PSMPLWVJMQEVPCP1.jpg'}}],
#           'type': 'others'}],
#         'summary': '6 likes'},
#        'logView': True,
#        'photo': {'createdAt': 1364528237,
#         'height': 431,
#         'id': '51550c6de4b0d47d962fd4d1',
#         'prefix': 'https://irs0.4sqi.net/img/general/',
#         'source': {'name': 'Foursquare for Android',
#          'url': 'https://foursquare.com/download/#/android'},
#         'suffix': '/2412989_C2jdgCg4uOPTuyW-XLpubeBc0QHuH5-9Yk8LY6O8c5Q.jpg',
#         'visibility': 'public',
#         'width': 720},
#        'photourl': 'https://irs0.4sqi.net/img/general/original/2412989_C2jdgCg4uOPTuyW-XLpubeBc0QHuH5-9Yk8LY6O8c5Q.jpg',
#        'text': "Must, must try the sugar cured bacon. It's some of the best bacon I've ever had",
#        'todo': {'count': 0},
#        'type': 'user',
#        'user': {'firstName': 'Janelle',
#         'gender': 'female',
#         'id': '2412989',
#         'isAnonymous': False,
#         'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#          'suffix': '/2KO4VOTT0V3WSEBG.jpg'}}},
#       {'agreeCount': 6,
#        'canonicalUrl': 'https://foursquare.com/item/50835f88e4b0e99d0bf4397d',
#        'createdAt': 1350786952,
#        'disagreeCount': 0,
#        'id': '50835f88e4b0e99d0bf4397d',
#        'lang': 'en',
#        'likes': {'count': 6,
#         'groups': [{'count': 6,
#           'items': [{'firstName': 'Andrew',
#             'gender': 'male',
#             'id': '112530',
#             'isAnonymous': False,
#             'lastName': 'Furman',
#             'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#              'suffix': '/112530-A2LYQEJSPLJQQTVD.jpg'}},
#            {'firstName': 'Dejay',
#             'gender': 'male',
#             'id': '20398258',
#             'isAnonymous': False,
#             'lastName': 'R',
#             'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#              'suffix': '/20398258-4T3IPCCRVXCLU2GN.jpg'}},
#            {'firstName': 'Matt',
#             'gender': 'male',
#             'id': '11427956',
#             'isAnonymous': False,
#             'lastName': 'Fitzpatrick',
#             'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#              'suffix': '/2LWKKEFPJ035ZCKH.jpg'}},
#            {'firstName': 'Nicholas',
#             'gender': 'male',
#             'id': '12463010',
#             'isAnonymous': False,
#             'lastName': 'VanderBorgh',
#             'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#              'suffix': '/A54C3UVPXLZP5YAR.jpg'}}],
#           'type': 'others'}],
#         'summary': '6 likes'},
#        'logView': True,
#        'text': 'i thought i had my hypothetical last meals all figured out until i had the blueberry pancakes here. unreal.',
#        'todo': {'count': 1},
#        'type': 'user',
#        'user': {'firstName': 'Jordan',
#         'gender': 'female',
#         'id': '507183',
#         'isAnonymous': False,
#         'lastName': 'Kong',
#         'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#          'suffix': '/ZNJJRRSMON5KSXDD.jpg'}}},
#       {'agreeCount': 6,
#        'canonicalUrl': 'https://foursquare.com/item/4f493b60e4b0186353f71d9f',
#        'createdAt': 1330199392,
#        'disagreeCount': 0,
#        'id': '4f493b60e4b0186353f71d9f',
#        'lang': 'en',
#        'likes': {'count': 6,
#         'groups': [{'count': 6,
#           'items': [{'firstName': 'Lateria',
#             'gender': 'female',
#             'id': '1245113',
#             'isAnonymous': False,
#             'lastName': 'Clemmons',
#             'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#              'suffix': '/1245113-FP3GSUXHBX5BA3QU.jpg'}},
#            {'firstName': 'Kevin',
#             'gender': 'male',
#             'id': '3160302',
#             'isAnonymous': False,
#             'lastName': 'Ennis',
#             'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#              'suffix': '/QDEVQ2HPDOUZQH5K.jpg'}},
#            {'firstName': 'Jasmine',
#             'gender': 'female',
#             'id': '1184206',
#             'isAnonymous': False,
#             'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#              'suffix': '/1184206-PSMPLWVJMQEVPCP1.jpg'}},
#            {'firstName': 'wenting',
#             'gender': 'female',
#             'id': '13947079',
#             'isAnonymous': False,
#             'lastName': 'xie',
#             'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#              'suffix': '/MPLGIKH4CSUOXR2U.jpg'}}],
#           'type': 'others'}],
#         'summary': '6 likes'},
#        'logView': True,
#        'text': 'Sugar Cured Bacon IS YOUR GOD. Worship it accordingly and offer it praise.',
#        'todo': {'count': 0},
#        'type': 'user',
#        'user': {'firstName': 'JP',
#         'gender': 'male',
#         'id': '46408',
#         'isAnonymous': False,
#         'lastName': 'Benini',
#         'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#          'suffix': '/LTE015BMHIMF3MA2.jpg'}}},
#       {'agreeCount': 6,
#        'canonicalUrl': 'https://foursquare.com/item/4c34ccbb6f1fef3bb7eeec3d',
#        'createdAt': 1278528699,
#        'disagreeCount': 0,
#        'id': '4c34ccbb6f1fef3bb7eeec3d',
#        'lang': 'en',
#        'likes': {'count': 6,
#         'groups': [{'count': 6,
#           'items': [{'firstName': 'Brunold',
#             'gender': 'male',
#             'id': '149405',
#             'isAnonymous': False,
#             'lastName': 'Loidl',
#             'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#              'suffix': '/149405-5UP3W0AUI50ZCDMH.jpg'}},
#            {'firstName': 'Elias',
#             'gender': 'male',
#             'id': '12314651',
#             'isAnonymous': False,
#             'lastName': 'Skaff',
#             'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#              'suffix': '/12314651-R5LHBBKBYMGARI45.jpg'}},
#            {'firstName': 'Michael',
#             'gender': 'male',
#             'id': '14878923',
#             'isAnonymous': False,
#             'lastName': 'Lou',
#             'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#              'suffix': '/EUQOTUTMT25HNK4P.jpg'}}],
#           'type': 'others'}],
#         'summary': '6 likes'},
#        'logView': True,
#        'text': "Our Readers' Choice WINNER for Best Brunch. We dare you stay away from their dessert cart of chocolate cake and muffins.",
#        'todo': {'count': 26},
#        'type': 'user',
#        'url': 'http://newyork.metromix.com/restaurants/pancakes/clinton-st-baking-company-lower-east-side/57113/content',
#        'user': {'firstName': 'Metromix',
#         'gender': 'none',
#         'id': '305584',
#         'isAnonymous': False,
#         'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#          'suffix': '/1TI0OUMNOTWTGBUM.jpg'},
#         'type': 'page'}},
#       {'agreeCount': 5,
#        'canonicalUrl': 'https://foursquare.com/item/51b87a22498e2a70c35dff5e',
#        'createdAt': 1371044386,
#        'disagreeCount': 0,
#        'id': '51b87a22498e2a70c35dff5e',
#        'lang': 'en',
#        'likes': {'count': 5,
#         'groups': [{'count': 5,
#           'items': [{'firstName': 'Zacky',
#             'gender': 'male',
#             'id': '187538',
#             'isAnonymous': False,
#             'lastName': 'Ma',
#             'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#              'suffix': '/187538-IT4FFG4PHFVXKGWX.jpg'}},
#            {'firstName': 'Andrew',
#             'gender': 'male',
#             'id': '13441308',
#             'isAnonymous': False,
#             'lastName': 'Kost',
#             'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#              'suffix': '/MJNI4ZM3U2DHGES0.gif'}},
#            {'firstName': 'Benjamin',
#             'gender': 'male',
#             'id': '26599605',
#             'isAnonymous': False,
#             'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#              'suffix': '/GLIDIFUV5YQVVOL5.jpg'}},
#            {'firstName': 'Grenlist.com',
#             'gender': 'female',
#             'id': '24724221',
#             'isAnonymous': False,
#             'lastName': 'Classifieds',
#             'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#              'suffix': '/ERTE5EZDDL5BLQET.jpg'}}],
#           'type': 'others'}],
#         'summary': '5 likes'},
#        'logView': True,
#        'photo': {'createdAt': 1371044387,
#         'height': 720,
#         'id': '51b87a23498edcf51da80ad9',
#         'prefix': 'https://irs3.4sqi.net/img/general/',
#         'source': {'name': 'Foursquare for iOS',
#          'url': 'https://foursquare.com/download/#/iphone'},
#         'suffix': '/5022019_81z4isTEo0d-CfyNiJeomlMidvV4BAWzxi10dB3Wt5g.jpg',
#         'visibility': 'public',
#         'width': 720},
#        'photourl': 'https://irs3.4sqi.net/img/general/original/5022019_81z4isTEo0d-CfyNiJeomlMidvV4BAWzxi10dB3Wt5g.jpg',
#        'text': 'Pies and cakes for grown-ups. Try the huevos rancheros.',
#        'todo': {'count': 1},
#        'type': 'user',
#        'user': {'firstName': 'Jeffrey',
#         'gender': 'male',
#         'id': '5022019',
#         'isAnonymous': False,
#         'lastName': 'Zeldman',
#         'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#          'suffix': '/5022019-FBQ05EOCXHQIVJOX'}}}],
#      'name': 'All tips',
#      'type': 'others'}]},
#   'url': 'http://www.clintonstreetbaking.com',
#   'venueChains': [],
#   'venuePage': {'id': '219374397'},
#   'verified': False}}

# %% [markdown]
# - Mendapatkan review dari user<br>
# Disini mendapatkan semua review user dari venue Pelangi. Hasil keluaran ber-format JSON

# %%
client.venues.tips('4c73518c376da09361e9a8c6', params={'limit': 500})
# Out:
# {'tips': {'count': 141,
#   'items': [{'agreeCount': 1,
#     'canonicalUrl': 'https://foursquare.com/item/53837e97498e6092bfe6c736',
#     'createdAt': 1401126551,
#     'disagreeCount': 0,
#     'id': '53837e97498e6092bfe6c736',
#     'likes': {'count': 1,
#      'groups': [{'count': 1,
#        'items': [{'firstName': 'Linda',
#          'gender': 'female',
#          'id': '110703851',
#          'isAnonymous': False,
#          'lastName': 'Sulistio',
#          'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#           'suffix': '/110703851-RJGDT1ORHWRBMLE5.jpg'}}],
#        'type': 'others'}],
#      'summary': '1 like'},
#     'logView': True,
#     'text': '😊😄😚😳😘',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Deasy Pusspita',
#      'gender': 'female',
#      'id': '68104193',
#      'isAnonymous': False,
#      'lastName': 'Pusspita Pane',
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/ACIYJMMZJDRCPVQ5.jpg'}}},
#    {'agreeCount': 0,
#     'authorInteractionType': 'liked',
#     'canonicalUrl': 'https://foursquare.com/item/5699db11498eed8e8abd0ad9',
#     'createdAt': 1452923665,
#     'disagreeCount': 0,
#     'id': '5699db11498eed8e8abd0ad9',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'photo': {'createdAt': 1452923729,
#      'height': 4160,
#      'id': '5699db51498ef7c41240e5f8',
#      'prefix': 'https://irs2.4sqi.net/img/general/',
#      'source': {'name': 'Foursquare for Android',
#       'url': 'https://foursquare.com/download/#/android'},
#      'suffix': '/70481962_sMq34Eh7sNxB2_soBlDKtV-zifS04fP_msz-Qby_PZ4.jpg',
#      'visibility': 'public',
#      'width': 3120},
#     'photourl': 'https://irs2.4sqi.net/img/general/original/70481962_sMq34Eh7sNxB2_soBlDKtV-zifS04fP_msz-Qby_PZ4.jpg',
#     'text': 'nice ambience, perfect taste.. just love it! sponge cheese cake trully best',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Krishna',
#      'gender': 'male',
#      'id': '70481962',
#      'isAnonymous': False,
#      'lastName': 'Zaini',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/70481962-KOO3BCJLDDJ3UIE2.jpg'}}},
#    {'agreeCount': 1,
#     'canonicalUrl': 'https://foursquare.com/item/548462cb498edc0ae7c27e93',
#     'createdAt': 1417962187,
#     'disagreeCount': 0,
#     'id': '548462cb498edc0ae7c27e93',
#     'lang': 'en',
#     'likes': {'count': 1,
#      'groups': [{'count': 1,
#        'items': [{'firstName': 'Linda',
#          'gender': 'female',
#          'id': '110703851',
#          'isAnonymous': False,
#          'lastName': 'Sulistio',
#          'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#           'suffix': '/110703851-RJGDT1ORHWRBMLE5.jpg'}}],
#        'type': 'others'}],
#      'summary': '1 like'},
#     'logView': True,
#     'text': 'Perfect for date, good taste, try tower lasagna. I bet you like chiffon cheese cake too',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Tatyana Putri',
#      'gender': 'female',
#      'id': '7014279',
#      'isAnonymous': False,
#      'lastName': 'Ariningrum',
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/CO2AMSLFSQJEASIZ.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/5642aa90498eef46cf731bcb',
#     'createdAt': 1447209616,
#     'disagreeCount': 0,
#     'id': '5642aa90498eef46cf731bcb',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'photo': {'createdAt': 1447209618,
#      'height': 225,
#      'id': '5642aa92498e60345dd6ec75',
#      'prefix': 'https://irs3.4sqi.net/img/general/',
#      'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'},
#      'suffix': '/123808499_zhKvggsj3V-d8tRxAYDnehSH1mEyh-7BOfhuljsqiOA.jpg',
#      'visibility': 'public',
#      'width': 300},
#     'photourl': 'https://irs3.4sqi.net/img/general/original/123808499_zhKvggsj3V-d8tRxAYDnehSH1mEyh-7BOfhuljsqiOA.jpg',
#     'text': 'Cream Leaupar merawat kecantikan wajah anda alami best seller asia 085697812506/PIN 75F1DD76 kunjungi kami di RAYKOSMETIK.BLOGSPOT.CO.ID',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Liany',
#      'gender': 'female',
#      'id': '123808499',
#      'isAnonymous': False,
#      'lastName': 'Fashionbeauty',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/123808499-5NYGWUHEIHJMG3TY.jpg'}}},
#    {'agreeCount': 0,
#     'authorInteractionType': 'meh',
#     'canonicalUrl': 'https://foursquare.com/item/55b60e32498edef46fc0c4ed',
#     'createdAt': 1437994546,
#     'disagreeCount': 0,
#     'id': '55b60e32498edef46fc0c4ed',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'photo': {'createdAt': 1437994584,
#      'height': 960,
#      'id': '55b60e58498efda4c920fdf1',
#      'prefix': 'https://irs3.4sqi.net/img/general/',
#      'source': {'name': 'Foursquare for Android',
#       'url': 'https://foursquare.com/download/#/android'},
#      'suffix': '/122652970_tG2wr5yIKCHoYJdBjgTDhVfntIm2spHaeuTKqnZ6cL8.jpg',
#      'visibility': 'public',
#      'width': 540},
#     'photourl': 'https://irs3.4sqi.net/img/general/original/122652970_tG2wr5yIKCHoYJdBjgTDhVfntIm2spHaeuTKqnZ6cL8.jpg',
#     'text': 'Tempatnya nyaman, Nasgor terasinya mantabzz...beef steak nya jg boleh dicoba dech...😙😙😙',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Andreas',
#      'gender': 'male',
#      'id': '122652970',
#      'isAnonymous': False,
#      'lastName': 'Fibrianto',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/122652970-5GUPFBOOPI4RW3EQ.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/51c18f76498e42cdd1f84f98',
#     'createdAt': 1371639670,
#     'disagreeCount': 0,
#     'id': '51c18f76498e42cdd1f84f98',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Cheese chiffon cakenya sukaaa bangettt..ice creamnya jga mantapp👍 and nasi goreng terasi bt pecinta pedasss!!!',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Gladys',
#      'gender': 'female',
#      'id': '5028672',
#      'isAnonymous': False,
#      'lastName': 'Putri',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/5XDQDEVJAHUC00DZ.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/52808cd711d2708b21b695ab',
#     'createdAt': 1384156375,
#     'disagreeCount': 0,
#     'id': '52808cd711d2708b21b695ab',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Good food, good price, good atmosphere.. but sometimes very crowded and hard to find parking lot..',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Antony',
#      'gender': 'male',
#      'id': '25159524',
#      'isAnonymous': False,
#      'lastName': 'Tjandra',
#      'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#       'suffix': '/VULX4GLABUV3IQJG.jpg'}}},
#    {'agreeCount': 0,
#     'authorInteractionType': 'liked',
#     'canonicalUrl': 'https://foursquare.com/item/5776461a498e5340f754353f',
#     'createdAt': 1467368986,
#     'disagreeCount': 0,
#     'id': '5776461a498e5340f754353f',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Makananya enak bgt recomend bgt eskrim. Carbonara nya jg enak bgt. Enak buat date sm hangout brg temen',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'aghnia',
#      'gender': 'none',
#      'id': '152127685',
#      'isAnonymous': False,
#      'lastName': 'azka amalia',
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/152127685-JWDMW3B1KCBQOBH2.jpg'}}},
#    {'agreeCount': 0,
#     'authorInteractionType': 'liked',
#     'canonicalUrl': 'https://foursquare.com/item/56407f39cd108cad866fbfa4',
#     'createdAt': 1447067449,
#     'disagreeCount': 0,
#     'id': '56407f39cd108cad866fbfa4',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Ayam goreng madu sama poffertjes nya enak,tempat cozy, pelayanan baik,harga reasonable..sip!',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Ridha',
#      'gender': 'female',
#      'id': '144899884',
#      'isAnonymous': False,
#      'lastName': 'Patria',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/144899884-I252GKH3BMVWIUHM.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4c84689b74d7b60c792f93d8',
#     'createdAt': 1283745947,
#     'disagreeCount': 0,
#     'id': '4c84689b74d7b60c792f93d8',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Es krim kopyornya enak bgt. Beef steaknya empuk. Tower lasagna bnr2 guede,rasanya mantap n pasti kenyang. Ke semarang,slain toko Oen,jg hrs kesini. :)',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'cinde kanes',
#      'gender': 'female',
#      'id': '1844636',
#      'isAnonymous': False,
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/424NGRPTXMOBJFMQ.jpg'}}},
#    {'agreeCount': 4,
#     'authorInteractionType': 'liked',
#     'canonicalUrl': 'https://foursquare.com/item/518a78bb498e5ea020036758',
#     'createdAt': 1368029371,
#     'disagreeCount': 0,
#     'id': '518a78bb498e5ea020036758',
#     'lang': 'en',
#     'likes': {'count': 4,
#      'groups': [{'count': 4,
#        'items': [{'firstName': 'Maya',
#          'gender': 'female',
#          'id': '7556740',
#          'isAnonymous': False,
#          'lastName': 'Sari',
#          'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#           'suffix': '/MT4DHPOCEI13QLKQ.jpg'}},
#         {'firstName': 'The',
#          'gender': 'male',
#          'id': '85322708',
#          'isAnonymous': False,
#          'lastName': 'Rony',
#          'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#           'suffix': '/85322708-HHTHBOXK2PRHDVDP.jpg'}},
#         {'firstName': 'Sri',
#          'gender': 'female',
#          'id': '66207494',
#          'isAnonymous': False,
#          'lastName': 'Mulyani',
#          'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#           'suffix': '/FAY5DRO1U2DNHSN1.jpg'}}],
#        'type': 'others'}],
#      'summary': '4 likes'},
#     'logView': True,
#     'text': 'Nasi goreng terasi, crispy duck, chicken grilled, and chiffon cake (˘ڡ˘)',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Yosephine  Endah',
#      'gender': 'female',
#      'id': '6449380',
#      'isAnonymous': False,
#      'lastName': 'Nur Diani',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/6449380-33SPWP0WTILW0CBB.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/503a2e12e4b0fc4e9f530b5f',
#     'createdAt': 1345990162,
#     'disagreeCount': 0,
#     'id': '503a2e12e4b0fc4e9f530b5f',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Nasi goreng trasinya mantap, coba utk liat view diatas, cukup romantis juga hehehe',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Jul',
#      'gender': 'female',
#      'id': '34759559',
#      'isAnonymous': False,
#      'lastName': 'Gakky',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/CCJGCMPYTPXIJD2K.jpg'}}},
#    {'agreeCount': 1,
#     'authorInteractionType': 'liked',
#     'canonicalUrl': 'https://foursquare.com/item/54640bb4498e9f1374204d50',
#     'createdAt': 1415842740,
#     'disagreeCount': 0,
#     'id': '54640bb4498e9f1374204d50',
#     'lang': 'id',
#     'likes': {'count': 1,
#      'groups': [{'count': 1,
#        'items': [{'firstName': 'muria',
#          'gender': 'female',
#          'id': '3995174',
#          'isAnonymous': False,
#          'lastName': 'seno',
#          'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#           'suffix': '/3995174-ZUDRNUJOJYEZ5H4X.jpg'}}],
#        'type': 'others'}],
#      'summary': '1 like'},
#     'logView': True,
#     'text': 'Tempat kenangan saya di pertemukan dg jodohku,di perkenalkan dg calon istri ku,dan sampai skg nikah',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Frolic Konveksi',
#      'gender': 'male',
#      'id': '58482192',
#      'isAnonymous': False,
#      'lastName': '(Kaos,Kemeja,Event,Atribut Parpol,Jacket,Polo,Totebag dll)',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/2V2QJYQ2OTCP3VXY.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/50f4f48ae4b027dc7449bdf0',
#     'createdAt': 1358230666,
#     'disagreeCount': 0,
#     'id': '50f4f48ae4b027dc7449bdf0',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Tower Lasagna ama chicken cordon bleu nya bikin nagihhh apalagi es krimnya hmmmm, , , mau lagii, ,',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Ipeh',
#      'gender': 'female',
#      'id': '15021180',
#      'isAnonymous': False,
#      'lastName': 'Latifah',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/XSIAT5TEL0N21FAH.jpg'}}},
#    {'agreeCount': 1,
#     'authorInteractionType': 'liked',
#     'canonicalUrl': 'https://foursquare.com/item/54e9f4ee498ea7ea5ba1ee61',
#     'createdAt': 1424618734,
#     'disagreeCount': 0,
#     'id': '54e9f4ee498ea7ea5ba1ee61',
#     'lang': 'id',
#     'likes': {'count': 1,
#      'groups': [{'count': 1, 'items': [], 'type': 'others'}],
#      'summary': '1 like'},
#     'logView': True,
#     'text': 'Klo ga mampir kesini rugi abiiis.krn harga terjangkau makananya verry delicious',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Linda',
#      'gender': 'female',
#      'id': '110703851',
#      'isAnonymous': False,
#      'lastName': 'Sulistio',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/110703851-RJGDT1ORHWRBMLE5.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/52236f6911d2da59b2f74c8d',
#     'createdAt': 1378053993,
#     'disagreeCount': 0,
#     'id': '52236f6911d2da59b2f74c8d',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'maka nikmat dunia mana yang kamu dustakan, apalagi lasagna tower yang menggoda~',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Tatyana Putri',
#      'gender': 'female',
#      'id': '7014279',
#      'isAnonymous': False,
#      'lastName': 'Ariningrum',
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/CO2AMSLFSQJEASIZ.jpg'}}},
#    {'agreeCount': 3,
#     'authorInteractionType': 'liked',
#     'canonicalUrl': 'https://foursquare.com/item/53f2a720498e5963ca010695',
#     'createdAt': 1408411424,
#     'disagreeCount': 0,
#     'id': '53f2a720498e5963ca010695',
#     'lang': 'en',
#     'likes': {'count': 3,
#      'groups': [{'count': 3,
#        'items': [{'firstName': 'Zulfika Fauzia',
#          'gender': 'female',
#          'id': '64290361',
#          'isAnonymous': False,
#          'lastName': 'Bilqist',
#          'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#           'suffix': '/64290361-SVMJJWUM2BV0BPCI.jpg'}},
#         {'firstName': 'Dono',
#          'gender': 'male',
#          'id': '76301507',
#          'isAnonymous': False,
#          'lastName': 'Joyo',
#          'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#           'suffix': '/76301507-DNUSKPCYMMCPGAUG.jpg'}},
#         {'firstName': 'Maya',
#          'gender': 'female',
#          'id': '7556740',
#          'isAnonymous': False,
#          'lastName': 'Sari',
#          'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#           'suffix': '/MT4DHPOCEI13QLKQ.jpg'}}],
#        'type': 'others'}],
#      'summary': '3 likes'},
#     'logView': True,
#     'text': 'Galantine nya okee... Lainnya so so. Ice cream is good. Fair price for a cafe',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Mercy',
#      'gender': 'female',
#      'id': '1225543',
#      'isAnonymous': False,
#      'lastName': 'Oktyasari',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/1225543-1VMH1KPX5QXK01DR.jpg'}}},
#    {'agreeCount': 1,
#     'canonicalUrl': 'https://foursquare.com/item/530befd0498e69fe8786af8c',
#     'createdAt': 1393291216,
#     'disagreeCount': 0,
#     'id': '530befd0498e69fe8786af8c',
#     'lang': 'id',
#     'likes': {'count': 1,
#      'groups': [{'count': 1,
#        'items': [{'firstName': 'Ryan',
#          'gender': 'male',
#          'id': '33090585',
#          'isAnonymous': False,
#          'lastName': 'Hari',
#          'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#           'suffix': '/E0J5SPJPL4RG3WL4.jpg'}}],
#        'type': 'others'}],
#      'summary': '1 like'},
#     'logView': True,
#     'photo': {'createdAt': 1393291219,
#      'height': 405,
#      'id': '530befd311d29bf11e5b789b',
#      'prefix': 'https://irs1.4sqi.net/img/general/',
#      'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'},
#      'suffix': '/79828899_11gJp5bn2xDBSs9wiDWywIZIHfiuXQH9kSNS_wEai8Q.jpg',
#      'visibility': 'public',
#      'width': 720},
#     'photourl': 'https://irs1.4sqi.net/img/general/original/79828899_11gJp5bn2xDBSs9wiDWywIZIHfiuXQH9kSNS_wEai8Q.jpg',
#     'text': 'paling demen sama chicken cordon blue nya',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'cendy',
#      'gender': 'female',
#      'id': '79828899',
#      'isAnonymous': False,
#      'lastName': 'anggara',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/-F5TTS3JAXXDNRMW0.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4fc85197e4b0cd33d1b64bb1',
#     'createdAt': 1338528151,
#     'disagreeCount': 0,
#     'id': '4fc85197e4b0cd33d1b64bb1',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': "Chiffon cake + zupa soup + carbonara :9 I'M STARVINGGGGGGGGG!!!",
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'nadia',
#      'gender': 'female',
#      'id': '8321428',
#      'isAnonymous': False,
#      'lastName': 'paramitha',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/RFNGWWUWQB20DECL.jpg'}}},
#    {'agreeCount': 2,
#     'canonicalUrl': 'https://foursquare.com/item/4f82e4f3e4b0c0cb05bd386e',
#     'createdAt': 1333978355,
#     'disagreeCount': 0,
#     'id': '4f82e4f3e4b0c0cb05bd386e',
#     'lang': 'id',
#     'likes': {'count': 2,
#      'groups': [{'count': 2,
#        'items': [{'firstName': 'Den Bagus Bayu',
#          'gender': 'male',
#          'id': '28511541',
#          'isAnonymous': False,
#          'lastName': 'Adi Putra',
#          'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#           'suffix': '/LJSUU55LZJGOWALH.jpg'}},
#         {'firstName': 'Ade',
#          'gender': 'male',
#          'id': '31352323',
#          'isAnonymous': False,
#          'lastName': 'Risky',
#          'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#           'suffix': '/00TNX0NXFAYQ4J1M.jpg'}}],
#        'type': 'others'}],
#      'summary': '2 likes'},
#     'logView': True,
#     'text': 'nasi goreng lidah. guava juice. chiffon cake + ice cream.... makkk nyusss',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'ina',
#      'gender': 'female',
#      'id': '4421551',
#      'isAnonymous': False,
#      'lastName': 'cahyaningtyas',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/4421551-PZL5WQ2YQ5HP5H0J.jpg'}}},
#    {'agreeCount': 0,
#     'authorInteractionType': 'liked',
#     'canonicalUrl': 'https://foursquare.com/item/55a53cf6498eaf8813390fee',
#     'createdAt': 1436892406,
#     'disagreeCount': 0,
#     'id': '55a53cf6498eaf8813390fee',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'photo': {'createdAt': 1436892409,
#      'height': 960,
#      'id': '55a53cf9498e08ebf3541bc2',
#      'prefix': 'https://irs1.4sqi.net/img/general/',
#      'source': {'name': 'Foursquare for Android',
#       'url': 'https://foursquare.com/download/#/android'},
#      'suffix': '/129848555_lAOiWV_vAlHp_PMimK9dAX8v_hZNsGOs7K9llhUA4pI.jpg',
#      'visibility': 'public',
#      'width': 720},
#     'photourl': 'https://irs1.4sqi.net/img/general/original/129848555_lAOiWV_vAlHp_PMimK9dAX8v_hZNsGOs7K9llhUA4pI.jpg',
#     'text': 'Chiffon kejunya luar biasaaa.... Enaaakk!!!',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Ndree',
#      'gender': 'female',
#      'id': '129848555',
#      'isAnonymous': False,
#      'lastName': 'Adler',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/129848555-ONVZZUOLG1ELGM1S.jpg'}}},
#    {'agreeCount': 1,
#     'authorInteractionType': 'liked',
#     'canonicalUrl': 'https://foursquare.com/item/5209c96811d210256191b56d',
#     'createdAt': 1376373096,
#     'disagreeCount': 0,
#     'id': '5209c96811d210256191b56d',
#     'lang': 'en',
#     'likes': {'count': 1,
#      'groups': [{'count': 1,
#        'items': [{'firstName': 'Dalas',
#          'gender': 'male',
#          'id': '13871802',
#          'isAnonymous': False,
#          'lastName': 'Delaware',
#          'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#           'suffix': '/13871802-STP1TSGXZVUI3THQ.jpg'}}],
#        'type': 'others'}],
#      'summary': '1 like'},
#     'logView': True,
#     'text': 'Crispy duck and chicken grilled nya nyummy :)',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Dalas',
#      'gender': 'male',
#      'id': '13871802',
#      'isAnonymous': False,
#      'lastName': 'Delaware',
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/13871802-STP1TSGXZVUI3THQ.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4c863a8688e6199c8003d1d4',
#     'createdAt': 1283865222,
#     'disagreeCount': 0,
#     'id': '4c863a8688e6199c8003d1d4',
#     'lang': 'id',
#     'likes': {'count': 1,
#      'groups': [{'count': 1, 'items': [], 'type': 'others'}],
#      'summary': '1 like'},
#     'logView': True,
#     'text': 'Ayam bakar madunya enak., bebeknya juga lumayan., tp yang pasti mesti beli Cheese chiffon cake nya.. recommm bgt deh., hehhee',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Lidya',
#      'gender': 'female',
#      'id': '3080809',
#      'isAnonymous': False,
#      'lastName': 'MAnik',
#      'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#       'suffix': '/K0UIYT4BC44UJBFZ.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/5155031fe4b092a6c165632c',
#     'createdAt': 1364525855,
#     'disagreeCount': 0,
#     'id': '5155031fe4b092a6c165632c',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Open at 7AM, and close at 11PM!',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Donny',
#      'gender': 'male',
#      'id': '28146378',
#      'isAnonymous': False,
#      'lastName': 'Fitrado',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/5NJGR1QSYWDNP4PN.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/51c6fb53498e977ee4d29498',
#     'createdAt': 1371994963,
#     'disagreeCount': 0,
#     'id': '51c6fb53498e977ee4d29498',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Strawberry & Cheese ice cream is  recommended.',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Rian',
#      'gender': 'male',
#      'id': '3015080',
#      'isAnonymous': False,
#      'lastName': 'Feldinanto',
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/S51UII4WV5EKXBQH.jpg'}}},
#    {'agreeCount': 1,
#     'canonicalUrl': 'https://foursquare.com/item/54b2462c498e4fb0c5362eee',
#     'createdAt': 1420969516,
#     'disagreeCount': 0,
#     'id': '54b2462c498e4fb0c5362eee',
#     'lang': 'id',
#     'likes': {'count': 1,
#      'groups': [{'count': 1,
#        'items': [{'firstName': 'Maulana',
#          'gender': 'male',
#          'id': '111987453',
#          'isAnonymous': False,
#          'lastName': 'Ardias',
#          'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#           'suffix': '/111987453-WEXUPNLJVGNNGJLI.jpg'}}],
#        'type': 'others'}],
#      'summary': '1 like'},
#     'logView': True,
#     'photo': {'createdAt': 1423414009,
#      'height': 960,
#      'id': '54d792f9498eeef55a5e1595',
#      'prefix': 'https://irs2.4sqi.net/img/general/',
#      'source': {'name': 'Foursquare for Android',
#       'url': 'https://foursquare.com/download/#/android'},
#      'suffix': '/111987453_c_CaQIeRiW8FBcEppQj1LgeK-b8ZlPbWqbl96AxVTms.jpg',
#      'visibility': 'public',
#      'width': 720},
#     'photourl': 'https://irs2.4sqi.net/img/general/original/111987453_c_CaQIeRiW8FBcEppQj1LgeK-b8ZlPbWqbl96AxVTms.jpg',
#     'text': 'Nasi goreng terasinya mantep !',
#     'todo': {'count': 1},
#     'type': 'user',
#     'user': {'firstName': 'Maulana',
#      'gender': 'male',
#      'id': '111987453',
#      'isAnonymous': False,
#      'lastName': 'Ardias',
#      'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#       'suffix': '/111987453-WEXUPNLJVGNNGJLI.jpg'}}},
#    {'agreeCount': 0,
#     'authorInteractionType': 'liked',
#     'canonicalUrl': 'https://foursquare.com/item/510d3293e4b0607ce86d8d1e',
#     'createdAt': 1359819411,
#     'disagreeCount': 0,
#     'id': '510d3293e4b0607ce86d8d1e',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Poffertjesnya (katanya) enak. Tapi sayangnya hanya sampai jam 17',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'wahyou',
#      'gender': 'male',
#      'id': '2265318',
#      'isAnonymous': False,
#      'lastName': 'ali',
#      'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#       'suffix': '/RJHCEMVIW1ZFIOZ2.jpg'}}},
#    {'agreeCount': 0,
#     'authorInteractionType': 'liked',
#     'canonicalUrl': 'https://foursquare.com/item/510d3532e4b0b5592fdc2c96',
#     'createdAt': 1359820082,
#     'disagreeCount': 0,
#     'id': '510d3532e4b0b5592fdc2c96',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Nasi Pelanginya juara. Juara enaknya juara banyaknya *laper',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'wahyou',
#      'gender': 'male',
#      'id': '2265318',
#      'isAnonymous': False,
#      'lastName': 'ali',
#      'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#       'suffix': '/RJHCEMVIW1ZFIOZ2.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/57e7ba62498e0ed6d5c76c03',
#     'createdAt': 1474804322,
#     'disagreeCount': 0,
#     'id': '57e7ba62498e0ed6d5c76c03',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Menu favorit di sini dorry oats sama pofertjies...enak deh...',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Ere',
#      'gender': 'female',
#      'id': '39336191',
#      'isAnonymous': False,
#      'lastName': 'Kusumaningrum',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/31SYC2JCICCDJJG0.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/50f7a93fe4b0f2d6f97fd4f9',
#     'createdAt': 1358407999,
#     'disagreeCount': 0,
#     'id': '50f7a93fe4b0f2d6f97fd4f9',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Enak enak masakannya. Nasi pelangi, cordon bleu . Top!',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Andrew',
#      'gender': 'male',
#      'id': '12275735',
#      'isAnonymous': False,
#      'lastName': 'Lie',
#      'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#       'suffix': '/12275735-0UPMXWASWLN45BKY.jpg'}}},
#    {'agreeCount': 3,
#     'canonicalUrl': 'https://foursquare.com/item/4f12dc80e4b0a6ade1b4aa09',
#     'createdAt': 1326636160,
#     'disagreeCount': 0,
#     'id': '4f12dc80e4b0a6ade1b4aa09',
#     'lang': 'en',
#     'likes': {'count': 3,
#      'groups': [{'count': 3,
#        'items': [{'firstName': 'patky',
#          'gender': 'male',
#          'id': '20665026',
#          'isAnonymous': False,
#          'lastName': 'speed',
#          'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#           'suffix': '/MFI1GQZ24VL22XKL.jpg'}},
#         {'firstName': 'Dita',
#          'gender': 'female',
#          'id': '10654207',
#          'isAnonymous': False,
#          'lastName': 'Vianto',
#          'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#           'suffix': '/AZ1DKMWW1BHFI5QZ.jpg'}}],
#        'type': 'others'}],
#      'summary': '3 likes'},
#     'logView': True,
#     'text': 'chiffon cheese cake & zupa soup, nyuum!',
#     'todo': {'count': 3},
#     'type': 'user',
#     'user': {'firstName': 'onik',
#      'gender': 'female',
#      'id': '3511112',
#      'isAnonymous': False,
#      'lastName': 'arfina',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/3511112-GHIG2BRDGXZXD04P.jpg'}}},
#    {'agreeCount': 1,
#     'canonicalUrl': 'https://foursquare.com/item/4f616b98e4b0deb11b4eab5f',
#     'createdAt': 1331784600,
#     'disagreeCount': 0,
#     'id': '4f616b98e4b0deb11b4eab5f',
#     'lang': 'en',
#     'likes': {'count': 1,
#      'groups': [{'count': 1,
#        'items': [{'firstName': 'Alix',
#          'gender': 'female',
#          'id': '24662601',
#          'isAnonymous': False,
#          'lastName': 'Valdivia',
#          'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#           'suffix': '/0XBG1C0EBJH0WIBU.jpg'}}],
#        'type': 'others'}],
#      'summary': '1 like'},
#     'logView': True,
#     'text': 'thank ai.sayangmu selembut chiffon cake se e nak banana split',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'intana',
#      'gender': 'female',
#      'id': '8145595',
#      'isAnonymous': False,
#      'lastName': 'baim',
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/RPURU02DP400CXC1.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/5224aada498e5dc669a84fb8',
#     'createdAt': 1378134746,
#     'disagreeCount': 0,
#     'id': '5224aada498e5dc669a84fb8',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Kuah steak nya kek semur.. teteup eskrimnya yg nyummy',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Yuyun',
#      'gender': 'female',
#      'id': '25717598',
#      'isAnonymous': False,
#      'lastName': 'Susanti',
#      'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#       'suffix': '/25717598-VF0YXZINZLMSZR0S.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/52770dd711d2e603b32f3c8a',
#     'createdAt': 1383534039,
#     'disagreeCount': 0,
#     'entities': [{'indices': [29, 58],
#       'object': {'url': 'http://www.penjualwebsite.com'},
#       'type': 'url'}],
#     'id': '52770dd711d2e603b32f3c8a',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Jasa buat website murah klik http://www.penjualwebsite.com  pin:27AAA6DA follow twitter @penjualwebsite #recomended.',
#     'todo': {'count': 0},
#     'type': 'user',
#     'url': 'http://www.penjualwebsite.com',
#     'user': {'firstName': 'Randhu',
#      'gender': 'male',
#      'id': '2478003',
#      'isAnonymous': False,
#      'lastName': 'Rindhu',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/G0TBW4VB2FAFT0XH.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/512505bde4b08b66775ae986',
#     'createdAt': 1361380797,
#     'disagreeCount': 0,
#     'id': '512505bde4b08b66775ae986',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'strawberry ice cream in here really nice!',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Ajeng',
#      'gender': 'female',
#      'id': '11792763',
#      'isAnonymous': False,
#      'lastName': 'Sista',
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/VB5O1YH4IGPXKOKB.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/5173a376e4b0f71f71f65722',
#     'createdAt': 1366532982,
#     'disagreeCount': 0,
#     'id': '5173a376e4b0f71f71f65722',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'photo': {'createdAt': 1366533007,
#      'height': 960,
#      'id': '5173a38fe4b043edc86c12f9',
#      'prefix': 'https://irs2.4sqi.net/img/general/',
#      'source': {'name': 'Foursquare for Android',
#       'url': 'https://foursquare.com/download/#/android'},
#      'suffix': '/36457445_6PZe7XM6yVzfLRZN34h3ZsGGgzCW6LJP4Fp6j55Au48.jpg',
#      'visibility': 'public',
#      'width': 518},
#     'photourl': 'https://irs2.4sqi.net/img/general/original/36457445_6PZe7XM6yVzfLRZN34h3ZsGGgzCW6LJP4Fp6j55Au48.jpg',
#     'text': 'Coffeenya siiip. Afogato nya pas!',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'A',
#      'gender': 'female',
#      'id': '36457445',
#      'isAnonymous': False,
#      'lastName': 'Uli',
#      'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#       'suffix': '/CG0SB0MCQE4J41EA.jpg'}}},
#    {'agreeCount': 2,
#     'canonicalUrl': 'https://foursquare.com/item/5311cc55498e8927d176722e',
#     'createdAt': 1393675349,
#     'disagreeCount': 0,
#     'id': '5311cc55498e8927d176722e',
#     'lang': 'id',
#     'likes': {'count': 2,
#      'groups': [{'count': 2,
#        'items': [{'firstName': "Fa'at",
#          'gender': 'male',
#          'id': '117402153',
#          'isAnonymous': False,
#          'lastName': 'Matsuzaka',
#          'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#           'suffix': '/117402153-XP4FZAO24CMVPOX3.jpg'}},
#         {'firstName': 'Linda',
#          'gender': 'female',
#          'id': '110703851',
#          'isAnonymous': False,
#          'lastName': 'Sulistio',
#          'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#           'suffix': '/110703851-RJGDT1ORHWRBMLE5.jpg'}}],
#        'type': 'others'}],
#      'summary': '2 likes'},
#     'logView': True,
#     'text': 'Cafe mantep menunya juga enak ..',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Oqi',
#      'gender': 'female',
#      'id': '12836514',
#      'isAnonymous': False,
#      'lastName': 'Paramita',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/12836514-5QVSS2IO0OCK2TXO.jpg'}}},
#    {'agreeCount': 1,
#     'canonicalUrl': 'https://foursquare.com/item/533686a511d2cfa327a33290',
#     'createdAt': 1396082341,
#     'disagreeCount': 0,
#     'id': '533686a511d2cfa327a33290',
#     'lang': 'en',
#     'likes': {'count': 1,
#      'groups': [{'count': 1,
#        'items': [{'firstName': 'Linda',
#          'gender': 'female',
#          'id': '110703851',
#          'isAnonymous': False,
#          'lastName': 'Sulistio',
#          'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#           'suffix': '/110703851-RJGDT1ORHWRBMLE5.jpg'}}],
#        'type': 'others'}],
#      'summary': '1 like'},
#     'logView': True,
#     'text': 'U must try their galantine..yummy!!!!',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Irene',
#      'gender': 'female',
#      'id': '3768445',
#      'isAnonymous': False,
#      'lastName': 'Rahardja',
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/3768445-M3F5TY0WOZEQL3Z4.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/521f238711d227dcaa4ee881',
#     'createdAt': 1377772423,
#     'disagreeCount': 0,
#     'id': '521f238711d227dcaa4ee881',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Love everything about cheese :3',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Mochtar',
#      'gender': 'male',
#      'id': '65014313',
#      'isAnonymous': False,
#      'lastName': 'Rizky Anantha',
#      'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#       'suffix': '/65014313-UMDOJN4E23R4QP2R.jpg'}}},
#    {'agreeCount': 0,
#     'authorInteractionType': 'liked',
#     'canonicalUrl': 'https://foursquare.com/item/55de9981498ed22090d98675',
#     'createdAt': 1440651649,
#     'disagreeCount': 0,
#     'id': '55de9981498ed22090d98675',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Try the cake. Cocok buat oleh2 juga',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Irwan',
#      'gender': 'male',
#      'id': '27431894',
#      'isAnonymous': False,
#      'lastName': 'Gunanto',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/2RBWDPYZQCKTXZGL.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4d462e914ede8eec47130a37',
#     'createdAt': 1296445073,
#     'disagreeCount': 0,
#     'id': '4d462e914ede8eec47130a37',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'umm, aku suka makan es krim, gelato n cheese chiffon cake-nya... :D',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'dina',
#      'gender': 'female',
#      'id': '6459180',
#      'isAnonymous': False,
#      'lastName': 'ariani sekarnegari',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/5IZPKTH42WSJ1AQC.jpg'}}},
#    {'agreeCount': 0,
#     'authorInteractionType': 'liked',
#     'canonicalUrl': 'https://foursquare.com/item/5487a039498ec06638a5377f',
#     'createdAt': 1418174521,
#     'disagreeCount': 0,
#     'id': '5487a039498ec06638a5377f',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Chiffon cake nya yoi banget. Sayangnya yang pandan harus pesen dulu kalo mau beli',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Pitoet',
#      'gender': 'male',
#      'id': '955197',
#      'isAnonymous': False,
#      'lastName': 'Noegroho 🔴',
#      'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#       'suffix': '/955197-J31YRF0YI3D2AK1L.jpg'}}},
#    {'agreeCount': 0,
#     'authorInteractionType': 'liked',
#     'canonicalUrl': 'https://foursquare.com/item/57f09282498e4873526c6b41',
#     'createdAt': 1475383938,
#     'disagreeCount': 0,
#     'id': '57f09282498e4873526c6b41',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Roti kejunya enak banget',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Made Hendra',
#      'gender': 'male',
#      'id': '1394469',
#      'isAnonymous': False,
#      'lastName': 'Putra',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/5DW014DCJHTO0FMP.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/520b81a7498eb0db0944f4ea',
#     'createdAt': 1376485799,
#     'disagreeCount': 0,
#     'id': '520b81a7498eb0db0944f4ea',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'paling demen sama chicken cordon blue nya',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Angga',
#      'gender': 'male',
#      'id': '3064849',
#      'isAnonymous': False,
#      'lastName': 'Kusuma',
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/2D3ILL3TRJK4RTYT.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4ec20b5e8231b62f435dcb53',
#     'createdAt': 1321339742,
#     'disagreeCount': 0,
#     'id': '4ec20b5e8231b62f435dcb53',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Nasi goreng terasi nya enak n pedes bangeeett!!!',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Gaby',
#      'gender': 'female',
#      'id': '3289070',
#      'isAnonymous': False,
#      'lastName': 'Cininta',
#      'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#       'suffix': '/L0HW1F4YRSEWN1SJ.jpg'}}},
#    {'agreeCount': 4,
#     'canonicalUrl': 'https://foursquare.com/item/5108bbd0e4b039fa9f0a9c8d',
#     'createdAt': 1359526864,
#     'disagreeCount': 0,
#     'id': '5108bbd0e4b039fa9f0a9c8d',
#     'lang': 'id',
#     'likes': {'count': 4,
#      'groups': [{'count': 4,
#        'items': [{'firstName': 'Dianmutiara',
#          'gender': 'female',
#          'id': '46237257',
#          'isAnonymous': False,
#          'lastName': 'Saputri',
#          'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#           'suffix': '/R13INKA2SWXRA15P.jpg'}},
#         {'firstName': 'Vivi',
#          'gender': 'female',
#          'id': '56253610',
#          'isAnonymous': False,
#          'lastName': 'Prayogo',
#          'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#           'suffix': '/ATQAGB10FJEDZVNS.jpg'}},
#         {'firstName': 'maryudi',
#          'gender': 'male',
#          'id': '51786717',
#          'isAnonymous': False,
#          'lastName': 'yudi',
#          'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#           'suffix': '/UE1I0STW3FRYZBCQ.jpg'}},
#         {'firstName': 'Atika',
#          'gender': 'female',
#          'id': '46485940',
#          'isAnonymous': False,
#          'lastName': 'Fajrhea',
#          'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#           'suffix': '/IUF0YXWQINM1UZQQ.jpg'}}],
#        'type': 'others'}],
#      'summary': '4 likes'},
#     'logView': True,
#     'text': 'Makanannya+es krimnya enak,tempatnya nyaman!',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Dianmutiara',
#      'gender': 'female',
#      'id': '46237257',
#      'isAnonymous': False,
#      'lastName': 'Saputri',
#      'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#       'suffix': '/R13INKA2SWXRA15P.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4d9709bb744f37049484c957',
#     'createdAt': 1301744059,
#     'disagreeCount': 0,
#     'id': '4d9709bb744f37049484c957',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Beef steak nya JUARA! Meskipun size nya mini..',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'aulia',
#      'gender': 'female',
#      'id': '1732817',
#      'isAnonymous': False,
#      'lastName': 'hasan',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/5I4FKEDPB4JUFCUP.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4cc440ffd43ba1430fac65f8',
#     'createdAt': 1287930111,
#     'disagreeCount': 0,
#     'id': '4cc440ffd43ba1430fac65f8',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Sekarang lebih pro, ada manager juga.. Mbak2nya sudah ngga berisik banget ngerumpi sendiri.. Overall makanan kok +sedikit ya..',
#     'todo': {'count': 1},
#     'type': 'user',
#     'user': {'firstName': 'Yohan',
#      'gender': 'male',
#      'id': '1519379',
#      'isAnonymous': False,
#      'lastName': 'Pratama',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/PJQL5MH40GVB4RFA.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/5699a3dc498eb1eca94f2e40',
#     'createdAt': 1452909532,
#     'disagreeCount': 0,
#     'id': '5699a3dc498eb1eca94f2e40',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'photo': {'createdAt': 1452909536,
#      'height': 540,
#      'id': '5699a3e0498ebc18ba8f782b',
#      'prefix': 'https://irs2.4sqi.net/img/general/',
#      'source': {'name': 'Foursquare for Android',
#       'url': 'https://foursquare.com/download/#/android'},
#      'suffix': '/6562774_ChelqzXKvZGajQvkXahEoWFtu-7w_aF5eU--WIsXZxE.jpg',
#      'visibility': 'public',
#      'width': 960},
#     'photourl': 'https://irs2.4sqi.net/img/general/original/6562774_ChelqzXKvZGajQvkXahEoWFtu-7w_aF5eU--WIsXZxE.jpg',
#     'text': 'Favorit deh ...',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'nira',
#      'gender': 'female',
#      'id': '6562774',
#      'isAnonymous': False,
#      'lastName': 'putri',
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/6562774-JKHHL0OZXK3GIQUA.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/539d84ba498e62d47e753897',
#     'createdAt': 1402832058,
#     'disagreeCount': 0,
#     'id': '539d84ba498e62d47e753897',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Eat all. Leave the plate.',
#     'todo': {'count': 1},
#     'type': 'user',
#     'user': {'firstName': 'Nana',
#      'gender': 'female',
#      'id': '52933962',
#      'isAnonymous': False,
#      'lastName': 'Nina',
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/52933962-NYLFN4BR0SENDENY.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/521468a411d2cb78f924ee70',
#     'createdAt': 1377069220,
#     'disagreeCount': 0,
#     'id': '521468a411d2cb78f924ee70',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'enak n gurih makananya',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'dave',
#      'gender': 'male',
#      'id': '62383047',
#      'isAnonymous': False,
#      'lastName': 'parfume',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/MV5D3X0AKA3FC2NT'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/509390d3e4b0f71701d8e9aa',
#     'createdAt': 1351848147,
#     'disagreeCount': 0,
#     'id': '509390d3e4b0f71701d8e9aa',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Try the strawberry ice cream. How nice this is<3',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'shabrina',
#      'gender': 'female',
#      'id': '14968796',
#      'isAnonymous': False,
#      'lastName': 'h',
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/EJHQ3IKWJ5KVS0MU.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4f91358ce4b09d834fc65988',
#     'createdAt': 1334916492,
#     'disagreeCount': 0,
#     'id': '4f91358ce4b09d834fc65988',
#     'lang': 'en',
#     'likes': {'count': 1,
#      'groups': [{'count': 1, 'items': [], 'type': 'others'}],
#      'summary': '1 like'},
#     'logView': True,
#     'text': 'Zupa soup, mmm yummi...',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'wahyu',
#      'gender': 'male',
#      'id': '7000176',
#      'isAnonymous': False,
#      'lastName': 'prasetio',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/CPWMEMTD2SY05N1E.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4c7a295e76ce9c74dc30af0c',
#     'createdAt': 1283074398,
#     'disagreeCount': 0,
#     'id': '4c7a295e76ce9c74dc30af0c',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'order the ice cream .. its so delicious  :D',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Mey',
#      'gender': 'female',
#      'id': '2986372',
#      'isAnonymous': False,
#      'lastName': 'Rina',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/I3PRYE3BJPY5YZES.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4c879bc1d92ea09370647772',
#     'createdAt': 1283955649,
#     'disagreeCount': 0,
#     'id': '4c879bc1d92ea09370647772',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Awful delicious to order: Yoghurt Gelato (manggo&guava)',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Nancy',
#      'gender': 'female',
#      'id': '1966417',
#      'isAnonymous': False,
#      'lastName': 'Liwikasari',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/DK1Z1CDK1M2W3RHT.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4fb34dd5e4b0947c3d4f3977',
#     'createdAt': 1337150933,
#     'disagreeCount': 0,
#     'id': '4fb34dd5e4b0947c3d4f3977',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'chiffon cake and ice cream(ˆڡˆ)',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Siti',
#      'gender': 'female',
#      'id': '28092003',
#      'isAnonymous': False,
# ...
#     'type': 'user',
#     'user': {'firstName': 'Gunawan',
#      'gender': 'male',
#      'id': '2979417',
#      'isAnonymous': False,
#      'lastName': 'Triwibowo',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/VLOKDEW5OSW054BE.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4d57d4ef8147f04dd0259b54',
#     'createdAt': 1297601775,
#     'disagreeCount': 0,
#     'id': '4d57d4ef8147f04dd0259b54',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'pelayan nya skrg jutek dan galak..dipanggil" jawabnya galak gitu',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Adrian',
#      'gender': 'male',
#      'id': '2745009',
#      'isAnonymous': False,
#      'lastName': 'Pratama',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/2745009-TIA4CZO0G5MAAJXW.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/512b2c5fe4b0861e67455e75',
#     'createdAt': 1361783903,
#     'disagreeCount': 0,
#     'id': '512b2c5fe4b0861e67455e75',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'nyam..nyamm',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Ricky',
#      'gender': 'male',
#      'id': '49105965',
#      'isAnonymous': False,
#      'lastName': 'Panggabean',
#      'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#       'suffix': '/01IW1WF4ZD0Q2TZN.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/503884f5e4b0024b23d5b858',
#     'createdAt': 1345881333,
#     'disagreeCount': 0,
#     'id': '503884f5e4b0024b23d5b858',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'With Mom&Dad\ue418',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Chikita Kintan',
#      'gender': 'female',
#      'id': '28403903',
#      'isAnonymous': False,
#      'photo': {'default': True,
#       'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/blank_girl.png'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4d3be2143ec9a35d2ec14381',
#     'createdAt': 1295770132,
#     'disagreeCount': 0,
#     'id': '4d3be2143ec9a35d2ec14381',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Jangan duduk diluar,gak bakalan dilayanin',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Selo',
#      'gender': 'male',
#      'id': '4547719',
#      'isAnonymous': False,
#      'lastName': 'Kahar',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/4547719-LRKYBBUZR5JLAGMQ.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4e979e7cf9f413b04cbd5a03',
#     'createdAt': 1318559356,
#     'disagreeCount': 0,
#     'id': '4e979e7cf9f413b04cbd5a03',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'MeRiNdUkAn BeRsAmAmU DiSiNi.....',
#     'todo': {'count': 1},
#     'type': 'user',
#     'user': {'firstName': 'Dion',
#      'gender': 'male',
#      'id': '13385664',
#      'isAnonymous': False,
#      'lastName': 'Takpatutdicinta',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/RVOLEKQQZOMXTLPB.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/525cd97911d20416c3a1b610',
#     'createdAt': 1381816697,
#     'disagreeCount': 0,
#     'id': '525cd97911d20416c3a1b610',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'makan duluu',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Fajrin',
#      'gender': 'female',
#      'id': '58354705',
#      'isAnonymous': False,
#      'lastName': 'Nidha',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/GSM4AMYCNRDOC44T.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4cc30215f49676b02eb771d5',
#     'createdAt': 1287848469,
#     'disagreeCount': 0,
#     'id': '4cc30215f49676b02eb771d5',
#     'lang': 'en',
#     'likes': {'count': 1,
#      'groups': [{'count': 1, 'items': [], 'type': 'others'}],
#      'summary': '1 like'},
#     'logView': True,
#     'text': 'semuanya mah enaaakkk.. :d~~',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Novita',
#      'gender': 'female',
#      'id': '1805469',
#      'isAnonymous': False,
#      'lastName': 'Hapsari',
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/ATPDAGCSEVDJUS12.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/55c9972a498e30c6485e1229',
#     'createdAt': 1439274794,
#     'disagreeCount': 0,
#     'id': '55c9972a498e30c6485e1229',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Maksi yuks ...',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Retno',
#      'gender': 'female',
#      'id': '46349871',
#      'isAnonymous': False,
#      'lastName': 'Adiyani',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/46349871-MP3ORQUM1KUM0UHP.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4f4635dde4b0ab39f54bd59d',
#     'createdAt': 1330001373,
#     'disagreeCount': 0,
#     'id': '4f4635dde4b0ab39f54bd59d',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Laperrr....',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'rio',
#      'gender': 'male',
#      'id': '3643298',
#      'isAnonymous': False,
#      'lastName': 'pramudya',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/5CALUX0XLH1YCRD1.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4e4e407952b1e893ad495619',
#     'createdAt': 1313751161,
#     'disagreeCount': 0,
#     'id': '4e4e407952b1e893ad495619',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'good place but too expensive',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Aloysius',
#      'gender': 'male',
#      'id': '11248225',
#      'isAnonymous': False,
#      'lastName': 'Setyo',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/11248225-LPQWYBNNB40EERBF.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4e12f13c6365b168494d3869',
#     'createdAt': 1309864252,
#     'disagreeCount': 0,
#     'id': '4e12f13c6365b168494d3869',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Sek, mau kesiniii',
#     'todo': {'count': 2},
#     'type': 'user',
#     'user': {'firstName': 'tita',
#      'gender': 'female',
#      'id': '8196553',
#      'isAnonymous': False,
#      'lastName': 'rahanip',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/NPITPCO42ADA25HA.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4c815ea4d6ebbfb7dd3844a4',
#     'createdAt': 1283546788,
#     'disagreeCount': 0,
#     'id': '4c815ea4d6ebbfb7dd3844a4',
#     'lang': 'en',
#     'likes': {'count': 1,
#      'groups': [{'count': 1, 'items': [], 'type': 'others'}],
#      'summary': '1 like'},
#     'logView': True,
#     'text': 'i like it ..',
#     'todo': {'count': 1},
#     'type': 'user',
#     'user': {'firstName': 'Lady',
#      'gender': 'female',
#      'id': '2052269',
#      'isAnonymous': False,
#      'lastName': 'SparkLe',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/MGFNB1RR0AGIRNWP.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4cfb2bd8feec6dcbfc3a4536',
#     'createdAt': 1291529176,
#     'disagreeCount': 0,
#     'id': '4cfb2bd8feec6dcbfc3a4536',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Srawberry Cheesenya Istimewa Dihati',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Tommy',
#      'gender': 'male',
#      'id': '4836052',
#      'isAnonymous': False,
#      'lastName': 'Soehendro',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/BL0THTWK3YXD0Z35.jpg'}}},
#    {'agreeCount': 1,
#     'authorInteractionType': 'liked',
#     'canonicalUrl': 'https://foursquare.com/item/5443bba7498edd07cb2db2c3',
#     'createdAt': 1413725095,
#     'disagreeCount': 0,
#     'id': '5443bba7498edd07cb2db2c3',
#     'lang': 'jv',
#     'likes': {'count': 1,
#      'groups': [{'count': 1,
#        'items': [{'firstName': 'sassy802',
#          'gender': 'male',
#          'id': '324224',
#          'isAnonymous': False,
#          'lastName': '⁽⁽٩(๑˃̶͈̀ ᗨ ˂̶͈́)۶⁾⁾',
#          'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#           'suffix': '/324224-IMCXYHM0IPNAQLQO.jpg'}}],
#        'type': 'others'}],
#      'summary': '1 like'},
#     'logView': True,
#     'photo': {'createdAt': 1413725212,
#      'height': 2448,
#      'id': '5443bc1c498ecc2a6f5a6962',
#      'prefix': 'https://irs2.4sqi.net/img/general/',
#      'source': {'name': 'Foursquare for Android',
#       'url': 'https://foursquare.com/download/#/android'},
#      'suffix': '/3762598_1g_0fDrP78EhE8Xm8VCfuoibTgucbqTGF5esvO7iTT8.jpg',
#      'visibility': 'public',
#      'width': 3264},
#     'photourl': 'https://irs2.4sqi.net/img/general/original/3762598_1g_0fDrP78EhE8Xm8VCfuoibTgucbqTGF5esvO7iTT8.jpg',
#     'text': 'Smoked chicken salad nya bikin kenyang nom nom nom~',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Devi Yohanita',
#      'gender': 'female',
#      'id': '3762598',
#      'isAnonymous': False,
#      'lastName': 'Qorina',
#      'photo': {'prefix': 'https://irs3.4sqi.net/img/user/',
#       'suffix': '/1MS0QOWRWNRNPL1T.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4c6d11511fb2a143cd08fde6',
#     'createdAt': 1282216273,
#     'disagreeCount': 0,
#     'id': '4c6d11511fb2a143cd08fde6',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Setuju sama @maswahjo, tukang parkirnya HOAX',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Yodha',
#      'gender': 'male',
#      'id': '1048925',
#      'isAnonymous': False,
#      'lastName': 'Sapi',
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/OOKAP2RYITYQO3Z3.jpg'}}},
#    {'agreeCount': 0,
#     'authorInteractionType': 'liked',
#     'canonicalUrl': 'https://foursquare.com/item/4bd7f7a270c603bbb68199b4',
#     'createdAt': 1272444834,
#     'disagreeCount': 0,
#     'id': '4bd7f7a270c603bbb68199b4',
#     'lang': 'en',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'biasanya wifi-nya cuepet, tumben niy lemoootzzz.....',
#     'todo': {'count': 1},
#     'type': 'user',
#     'user': {'firstName': 'dini',
#      'gender': 'female',
#      'id': '107826',
#      'isAnonymous': False,
#      'lastName': 'primasanti',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/107826-4LM4WRYADDSGH2BR.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4f73fc9ae4b04f5d5c1a86a7',
#     'createdAt': 1333001370,
#     'disagreeCount': 0,
#     'id': '4f73fc9ae4b04f5d5c1a86a7',
#     'lang': 'id',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'parah gak ada mushalla disini...',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Sandy Harselan Pradana',
#      'gender': 'male',
#      'id': '1846181',
#      'isAnonymous': False,
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/YUWWSWYDVG10CYMM.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4f4c6ed9e4b0577d7f9f568c',
#     'createdAt': 1330409177,
#     'disagreeCount': 0,
#     'id': '4f4c6ed9e4b0577d7f9f568c',
#     'lang': 'ms',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Mas pelayan nya yg itu muka nya jutek (˘_˘")',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Khumayroh Rachmawati',
#      'gender': 'female',
#      'id': '5069156',
#      'isAnonymous': False,
#      'lastName': 'Buana',
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/5069156-42XHCADZVHIYTDA3.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/547ac5be11d24229a381ba4b',
#     'createdAt': 1417332158,
#     'disagreeCount': 0,
#     'id': '547ac5be11d24229a381ba4b',
#     'lang': 'zh',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Ic cream😬😬',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'panji prawira',
#      'gender': 'male',
#      'id': '5613336',
#      'isAnonymous': False,
#      'lastName': 'pradhana',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/5613336-UR4AQVEPYU04J1HR.jpg'}}},
#    {'agreeCount': 2,
#     'canonicalUrl': 'https://foursquare.com/item/4fed45abe4b0430e0a39700b',
#     'createdAt': 1340949931,
#     'disagreeCount': 0,
#     'id': '4fed45abe4b0430e0a39700b',
#     'lang': 'ms',
#     'likes': {'count': 2,
#      'groups': [{'count': 2,
#        'items': [{'firstName': 'Pandu',
#          'gender': 'male',
#          'id': '36858550',
#          'isAnonymous': False,
#          'lastName': 'Karya',
#          'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#           'suffix': '/XNKZ4E1IRVW2PK4W.jpg'}},
#         {'firstName': 'Karina',
#          'gender': 'female',
#          'id': '31459673',
#          'isAnonymous': False,
#          'lastName': 'Afiqa',
#          'photo': {'default': True,
#           'prefix': 'https://irs2.4sqi.net/img/user/',
#           'suffix': '/blank_girl.png'}}],
#        'type': 'others'}],
#      'summary': '2 likes'},
#     'logView': True,
#     'text': 'Pengen bgt k sini :/',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'indanduut',
#      'gender': 'female',
#      'id': '24301990',
#      'isAnonymous': False,
#      'lastName': 'baiq',
#      'photo': {'prefix': 'https://irs0.4sqi.net/img/user/',
#       'suffix': '/U023XAUFSY51LSSA.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4d53cf2cc8d0f04d58bebad4',
#     'createdAt': 1297338156,
#     'disagreeCount': 0,
#     'id': '4d53cf2cc8d0f04d58bebad4',
#     'lang': 'jv',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Akika ngalami duduk diluar dan gg dilayani (-̩̩̩-͡ ̗--̩̩̩͡ )',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Windy',
#      'gender': 'female',
#      'id': '2691225',
#      'isAnonymous': False,
#      'lastName': 'Sumongga',
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/LD2R1SDQSLCMQBKW.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4ce3cfa4a3c6721e465712cf',
#     'createdAt': 1289998244,
#     'disagreeCount': 0,
#     'id': '4ce3cfa4a3c6721e465712cf',
#     'lang': 'jv',
#     'likes': {'count': 1,
#      'groups': [{'count': 1, 'items': [], 'type': 'others'}],
#      'summary': '1 like'},
#     'logView': True,
#     'text': 'Straberry ice cream cheese nya brlimpah keju ~(˘.˘~) ~(˘.˘)~ (~˘.˘)~',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'Warastra',
#      'gender': 'male',
#      'id': '3759425',
#      'isAnonymous': False,
#      'lastName': 'Adhi',
#      'photo': {'prefix': 'https://irs2.4sqi.net/img/user/',
#       'suffix': '/EMPQWQHC41X3F3GC.jpg'}}},
#    {'agreeCount': 0,
#     'canonicalUrl': 'https://foursquare.com/item/4d22fc2516cfb60c78be6d61',
#     'createdAt': 1294138405,
#     'disagreeCount': 0,
#     'id': '4d22fc2516cfb60c78be6d61',
#     'lang': 'jv',
#     'likes': {'count': 0, 'groups': []},
#     'logView': True,
#     'text': 'Wi-Fi nya \uf3feяέě°˚ ˚°eë†††....',
#     'todo': {'count': 0},
#     'type': 'user',
#     'user': {'firstName': 'norma',
#      'gender': 'female',
#      'id': '1463938',
#      'isAnonymous': False,
#      'lastName': 'farsha',
#      'photo': {'prefix': 'https://irs1.4sqi.net/img/user/',
#       'suffix': '/LVTXIY2EANNULZ2O.jpg'}}}]}}

# %% [markdown]
# - Menyimpan hasil review pada JSON

# %%
import json

with open('review_pelangi_35.json', 'w') as f:
    status = client.venues.tips('4c73518c376da09361e9a8c6', params={'limit': 500})
    f.write(json.dumps(status))

# %% [markdown]
# - Menyimpan hasil review pada CSV

# %%
import csv

status = client.venues.tips('4c73518c376da09361e9a8c6', params={'limit': 500})
count = status["tips"]["count"]

csvFile = open('review_pelangi_35.csv', 'w', newline='', encoding='utf8')
csvWriter = csv.writer(csvFile)

row = [ "nomer", "nama depan", "nama belakang" "text" ]
csvWriter.writerow(row)

for i in range(count):
    # untuk melakukan cek apakah Key lastName ada pada json
    if("lastName" in status["tips"]["items"][i]["user"]):
        nama_belakang = status["tips"]["items"][i]["user"]["lastName"]
    else:
        nama_belakang = ''
    nama_depan = status["tips"]["items"][i]["user"]["firstName"]
    text = status["tips"]["items"][i]["text"]
    
    csvWriter.writerow([i, nama_depan, nama_belakang, text])
csvFile.close()

# %% [markdown]
# ### 4. Facebook
# Facebook juga menyediakan API untuk mengambil data. Namun, memiliki keterbatasan pada API-nya
#
# #### a. Register App
# Lakukan register app di [sini](https://developers.facebook.com). Untuk mendapatkan access token dari Graph API Explorer bisa menuju ke [sini](https://developers.facebook.com/tools-and-support/). Saat ini kita akan menggunakan access token melalui [sini](https://developers.facebook.com/tools/explorer/145634995501895/)
# #### b. Install facebook library
# Untuk meng-install dapat menggunakan <u>pip install facebook-sdk</u>. Dokumentasi mengenai library facebook bisa diakses di [sini](https://pypi.python.org/pypi/facebook-sdk)

# %% [markdown]
# #### c. Inisialisasi

# %%
import facebook
import json

token = 'EAACEdEose0cBAFhPr6wijKPaHdWpYj184Iameqgrk3h72K88NJZBd2kfNTCrHZAnikXsqyZBxby1WZBmM2fZAduUwQnycUTRJAFxPuhbb9X4QvUQFZAYX0egfLA2t0qXimjZAEiILoUVI7kH4Q4eeJpxoh29L8ZADZBiabHJE4PDDUwZDZD'

graph = facebook.GraphAPI(token, version='2.4')

# %% [markdown]
# - Mendapatkan post facebook : disini mendapatkan post facebook pada status [berikut](https://www.facebook.com/yasirabdr/posts/10202364671435487?comment_id=10202365367372885&notif_t=feed_comment&notif_id=1477468971875752)
# <br>
# Id <b>1753611558_10202364671435487</b>, artinya <b>1753611558</b> adalah user_id dan <b>10202364671435487</b> adalah post_id
# <br>
# Untuk mendapatkan user_id bisa melalui [sini](http://findmyfbid.com/)

# %%
post = graph.get_object(id='1753611558_10202364671435487')
print(post['message'])
# Out:
# a

# %% [markdown]
# - Mendapatkan jumlah attending event : disini mendapatkan dari event facebook [berikut](https://www.facebook.com/events/152338271896393/permalink/152339035229650/?notif_t=event_mall_reply&notif_id=1477479240069992)
# <br>
# Id <b>152338271896393</b> merupakan event_id.

# %%
event = graph.get_object(id='152338271896393', fields='attending_count,declined_count')
print(event['attending_count'])
print(event['declined_count'])
# Out:
# 3
# 0

# %% [markdown]
# - Mendapatkan jumlah teman

# %%
# Get all of the authenticated user's friends
friends = graph.get_connections(id='me', connection_name='friends')

print(json.dumps(friends, indent=4))
# Out:
# {
#     "data": [
#         {
#             "id": "553501854",
#             "name": "Andri Yadi"
#         },
#         {
#             "id": "659694820",
#             "name": "Ibnu Sina Wardy"
#         },
#         {
#             "id": "702116903",
#             "name": "Adhil Abdat"
#         },
#         {
#             "id": "706495204",
#             "name": "Sofian Hadiwijaya"
#         },
#         {
#             "id": "749132299",
#             "name": "Brian Arfi Faridhi"
#         },
#         {
#             "id": "1031093453",
#             "name": "Noor Siti Halimah"
#         },
#         {
#             "id": "10203966558220740",
#             "name": "Ali Jaya Meilio"
#         },
#         {
#             "id": "1126861557",
#             "name": "Abdurrosyid Broto Handoyo"
#         },
#         {
#             "id": "1161974319",
#             "name": "Vriga Ramadhan Putra"
#         },
#         {
#             "id": "10203575999821779",
#             "name": "Muhammad Imran Hirawan"
#         },
#         {
#             "id": "1296602340",
#             "name": "Richard Vinc"
#         },
#         {
#             "id": "10202603162822824",
#             "name": "Sidiq Permana"
#         },
#         {
#             "id": "1332060892",
#             "name": "Aris Lesmana"
#         },
#         {
#             "id": "1335811482",
#             "name": "Lhuqita Fazry"
#         },
#         {
#             "id": "10202871488334689",
#             "name": "Arryangga Aliev Pratamaputra"
#         },
#         {
#             "id": "1459909409",
#             "name": "Dwi Aji Kurniawan"
#         },
#         {
#             "id": "1471116003",
#             "name": "Haydar Ali Ismail"
#         },
#         {
#             "id": "10203671084406217",
#             "name": "Sindunuraga R Putra"
#         },
#         {
#             "id": "10203460082733300",
#             "name": "Toni Haryanto"
#         },
#         {
#             "id": "1618235386",
#             "name": "Sonny Lazuardi Hermawan"
#         },
#         {
#             "id": "1619147610",
#             "name": "Kresna Galuh"
#         },
#         {
#             "id": "10204135280495908",
#             "name": "Wendi Rudi Madoe"
#         },
#         {
#             "id": "1683092457",
#             "name": "Budi Sunaryo"
#         },
#         {
#             "id": "10202099822296721",
#             "name": "Randi Dwi Nandra"
#         },
#         {
#             "id": "779598122062653",
#             "name": "Muhammad Muhlas Abror"
#         }
#     ],
#     "summary": {
#         "total_count": 1581
#     },
#     "paging": {
#         "cursors": {
#             "before": "QVFIUmExYno4U3pWOXlhb0RxTTZAuS1RIOXMwT1NxTnkxZAXREaU9NLXBXZAFZAXUkI0N2x2eW9xRFUzVGdiLUh3SnRxd3gZD",
#             "after": "QVFIUjN3OExYMlJ5RUV1US1zSFd2WGFaekdON08tQVZAkZAXhEWHNhRDhtam1JV19Xa0ZAPV2YtSEVFTGZA0ME5BbVB5RlJYZAkdaQUl3VkpDU3k2ZA3dzdlBnVWV3"
#         },
#         "next": "https://graph.facebook.com/v2.4/4429573754827/friends?access_token=EAACEdEose0cBAFhPr6wijKPaHdWpYj184Iameqgrk3h72K88NJZBd2kfNTCrHZAnikXsqyZBxby1WZBmM2fZAduUwQnycUTRJAFxPuhbb9X4QvUQFZAYX0egfLA2t0qXimjZAEiILoUVI7kH4Q4eeJpxoh29L8ZADZBiabHJE4PDDUwZDZD&limit=25&after=QVFIUjN3OExYMlJ5RUV1US1zSFd2WGFaekdON08tQVZAkZAXhEWHNhRDhtam1JV19Xa0ZAPV2YtSEVFTGZA0ME5BbVB5RlJYZAkdaQUl3VkpDU3k2ZA3dzdlBnVWV3"
#     }
# }

# %% [markdown]
# - Melakukan comment pada post facebook : disini melakukan comment post facebook pada status [berikut](https://www.facebook.com/yasirabdr/posts/10202364671435487?comment_id=10202365367372885&notif_t=feed_comment&notif_id=1477468971875752)
# <br>
# Id <b>1753611558_10202364671435487</b>, artinya <b>1753611558</b> adalah user_id dan <b>10202364671435487</b> adalah post_id

# %%
graph.put_object(parent_object='1753611558_10202364671435487', connection_name='comments',message='Tes API!')
# Out:
# {'id': '10202364671435487_10202401073625519'}

# %% [markdown]
# - Melakukan update status pada wall

# %%
# put_wall_post
attachment =  {
    'name': 'Link name',
    'link': 'https://www.example.com/',
    'caption': 'Check out this example',
    'description': 'This is a longer description of the attachment',
    'picture': 'https://www.example.com/thumbnail.jpg'
}

graph.put_wall_post(message='Check this out...', attachment=attachment)
# Out:
# {'id': '4429573754827_10202401073665520'}

# %% [markdown]
# - Melakukan comment pada post facebook

# %%
# put_comment
graph.put_comment(object_id='1753611558_10202364671435487', message='Great post...')
# Out:
# {'id': '10202364671435487_10202401074105531'}

# %% [markdown]
# - Melakukan 'like' pada object tertentu, misal : comment post facebook [berikut](https://www.facebook.com/yasirabdr/posts/10202364671435487?comment_id=10202365367372885&notif_t=feed_comment&notif_id=1477468971875752)

# %%
# put_like
graph.put_like(object_id='10202365367372885')
# Out:
# {'success': True}

# %% [markdown]
# - Mendapatkan post dari facebook kita dengan atribut tertentu

# %%
import requests

posts = graph.get_connections('me', 'posts', fields='message,created_time,description,caption,link,place,status_type,shares')
while True:  # keep paginating
    try:
        with open('my_posts_35.json', 'a') as f:
            for post in posts['data']:
                f.write(json.dumps(post)+"\n")
            # get next page
            posts = requests.get(posts['paging']['next']).json()
    except KeyError:
        # no more pages, break the loop
        break

# %% [markdown]
# - Mendapatkan profile facebook

# %%
profile = graph.get_object("me", fields='name,location{general_info,location},languages{name,description}')
print(json.dumps(profile, indent=4))
# Out:
# {
#     "id": "4429573754827",
#     "location": {
#         "id": "106330572737890",
#         "location": {
#             "latitude": -6.96667,
#             "city": "Semarang",
#             "country": "Indonesia",
#             "longitude": 110.417
#         }
#     },
#     "name": "Yasir Abdurrahman"
# }

# %% [markdown]
# ### 5. Instagram

# %% [markdown]
# Instagram juga menyediakan API untuk mengambil data. Namun, memiliki keterbatasan pada API-nya.
#
# #### a. Register App
# Lakukan register app di [sini](https://www.instagram.com/developer/). Untuk mendapatkan access token melalui link [sini](https://instagram.com/oauth/authorize/?client_id=[CLIENT_ID_HERE]&redirect_uri=http://localhost&response_type=token) dengan terlebih dahulu mendefinisikan pada app client redirect uri-nya.
# <br><br>
# Pastikan juga redirect uri yang terdapat pada app dan link di atas sama.
#
# #### b. Install instagram library
# Untuk meng-install dapat menggunakan <u>pip install python-instagram</u>. Dokumentasi mengenai library instagram bisa diakses pada github di [sini](https://github.com/facebookarchive/python-instagram). Walaupun library-nya sepertinya sudah tidak di-update lagi.

# %% [markdown]
# - Inisialisasi

# %%
from instagram.client import InstagramAPI

access_token = '1397096926.dc637bd.b8b3dc8571914eb09e95772139086196'
client_secret = 'ee7d8da7b1bb45dd9f2b66e75950682f'
api = InstagramAPI(access_token=access_token, client_secret=client_secret)

# %% [markdown]
# ### Catatan
# Jika mendapatkan error <i>KeyError : 'data'</i>. Lakukan langkah berikut:
# 1. Buka file <b>models.py</b> pada Anaconda, misalnya C:\Users\yasir\Anaconda3\Lib\site-packages\instagram
# 2. Kemudian pada line 99-101 tambah kode berikut ini

# %% [raw]
# if 'data' in entry['comments']:
#     for comment in entry['comments']['data']:
#         new_media.comments.append(Comment.object_from_dictionary(comment))

# %% [markdown]
# <b>PASTIKAN</b> indentasi benar dengan jumlah tab selebar 4 spaces.

# %% [markdown]
# - Mendapatkan caption
# <br>
# Angka <b>1397096926</b> merupakan user_id. Untuk mendapatkan user_id bisa melalui [ini](https://smashballoon.com/instagram-feed/find-instagram-user-id/)

# %%
recent_media, next_ = api.user_recent_media(user_id="1397096926", count=10)
for media in recent_media:
    print(media.caption.text)
# Out:
# Tes
# Selamat Reza & Reva. Semoga jadi keluarga samawa.
# Semoga bisa segera nyusul nikah juga 😆
# Developer Day! #Bekraf #Dicoding
# Kucing dalam pangkuan ._.
# Para manusia yang bertahan dari malam ke malam ... programmer..
# Hackathon Android Kejar
# Awal yang bagus, semoga informatika undip bisa dapet medali gemastik.
# MIT App Inventor ez android apps

# %% [markdown]
# - Mendapatkan user yang terdaftar pada app

# %%
api.user(1397096926)
# Out:
# User: yasirabdr

# %% [markdown]
# - Mendapatkan media yang disukai

# %%
api.user_liked_media()
# Out:
# ([], None)

# %% [markdown]
# - Mendapatkan detail user

# %%
user = api.user_search('yasirabdr')
my_usr = user[0]
print ('User id is', my_usr.id, 'and name is ', my_usr.username)
# Out:
# User id is 1397096926 and name is  yasirabdr

# %% [markdown]
# - Mendapatkan request masuk

# %%
api.user_incoming_requests()
# Out:
# []

# %% [markdown]
# - Melakukan follow user (hanya bisa pada user yang terdapat di app)

# %%
api.follow_user(user_id=1397096926)
# Out:
# ('', None)

# %% [markdown]
# - Melakukan unfollow user (hanya bisa pada user yang terdapat di app)

# %%
api.unfollow_user(user_id=1397096926)
# Out:
# (Relationship: (Follows: False, Followed by: False), None)

# %% [markdown]
# - Menampilkan comment pada post
# <br>
# Id <b>1372565131599223982_1397096926</b> merupakan media_id yang terdapat pada post [berikut](https://www.instagram.com/p/BMMVLcMDxyu/)
# <br>
# Untuk mendapatkan media_id gunakan url [berikut](https://api.instagram.com/oembed/?url=https://www.instagram.com/p/BMMVLcMDxyu/)
# <br>
# Untuk mendapatkan media_id yang lain, tinggal mengganti url-nya saja

# %%
api.media_comments(media_id='1372565131599223982_1397096926')
# Out:
# [Comment: yasirabdr said "this is my comment!",
#  Comment: yasirabdr said "soon to be deleted",
#  Comment: yasirabdr said "Dateng aja ke praktikum tkh setiap kamis jam 08.00 pagi @jundanaaa @faqihsch heee",
#  Comment: yasirabdr said "Di lab e2 @faqihsch @jundanaa",
#  Comment: yasirabdr said "Dateng aja @faqihsch belajar bareng hee",
#  Comment: yasirabdr said "Kan lab e2 @jundanaa",
#  Comment: yasirabdr said "this is my comment!"]

# %% [markdown]
# - Menuliskan comment

# %%
api.create_media_comment(media_id='1372565131599223982_1397096926', text='this is my comment!')
# Out:
# []

# %% [markdown]
# - Melakukan like

# %%
api.like_media(media_id='1372565131599223982_1397096926')
# Out:
# []

# %% [markdown]
# - Melakukan unlike

# %%
api.unlike_media(media_id='1372565131599223982_1397096926')
# Out:
# []

# %% [markdown]
# ### 6. Scrapping pada web ecommerce (Amazon)
# Melakukan scrapping adalah melakukan ekstraksi informasi pada suatu website. Pada proses scrapping yang digunakan kali ini menggunakan library python yaitu [Scrapy](https://scrapy.org/). Scrapy adalah framework untuk melakukan ekstraksi data pada web.
#
# ## Error  = Gagal Install Scrapy

# %% [markdown]
# #### a. Install Scrapy
# Cara mudah untuk melakukan install menggunakan <u>pip install Scrapy</u>

# %% [markdown]
# ### Catatan
# Jika gagal melakukan install dan mendapatkan <i>error : Microsoft Visual C++ 14.0 is required</i>. Maka lakukan install dengan men-download di [sini](http://landinghub.visualstudio.com/visual-cpp-build-tools).

# %% [markdown]
# #### b. Get Started with Scrapy
# Untuk memulai kita terlebih dahulu membuat sebuah projek baru melalui <b>console</b> dengan terlebih dahulu mengarahkan ke folder tujuan
# <br><br><b><pre>scrapy startproject bukalapak</pre></b><br>
# Dengan melakukan hal tersebut, maka otomatis akan menghasilkan seperti berikut:
# <br><b>
# <pre>bukalapak/
#     scrapy.cfg
#    bukalapak/
#        __init__.py
#        items.py
#        pipelines.py
#        settings.py
#        spiders/
#            __init__.py
# </pre>
# </b><br>
# Scrapy adalah <b>Object Oriented</b> programming dalam mendefinisikan item dan spider. Berikut penjelasan dari tiap item
# - <b>scrapy.cfg</b><br>
# It is a project configuration file which contains information for setting module for the project along with its deployment information.<br><br>
# - <b>bukalapak</b> : application directory
# <br><br>
# - <b>items.py</b><br>
# Items are containers that will be loaded with the scraped data; they work like simple <b>Python dicts</b>. While one can use plain Python dicts with Scrapy, Items provide additional protection against populating undeclared fields, preventing typos. They are declared by creating a <b>scrapy.Item</b> class and defining its attributes as <b>scrapy.Field</b> objects.
# <br><br>
# - <b>pipelines.py</b><br>
# After an item has been scraped by a spider, it is sent to the Item <b>Pipeline</b> which processes it through several components that are executed sequentially.Each item pipeline component is a Python class which has to implement a method called <b>process_item</b> to process scraped items. It receives an item and performs an action on it, also decides if the item should continue through the pipeline or should be dropped and and not processed any longer. If it wants to drop an item then it raises <b>DropItem</b> exception to drop it.
# <br><br>
# - <b>settings.py</b> : <br>
# It allows one to customise the behaviour of all Scrapy <b>components</b>, including the core, extensions, pipelines and spiders themselves. It provides a global namespace of key-value mappings that the code can use to pull configuration values from.
# <br><br>
# - <b>spiders</b> : <br>
# Spiders is a directory which contains all <b>spiders/crawlers</b> as Python classes. Whenever one runs/crawls any spider then scrapy looks into this directory and tries to find the spider with its name provided by user. Spiders define how a certain site or a group of sites will be scraped, including how to perform the crawl and how to extract data from their pages. In other words, Spiders are the place where one defines the custom behavior for crawling and parsing pages for a particular site.Spiders have to define three major attributes i.e <b>start_urls</b> which tells which URLs are to be scrapped, <b>allowed_domains</b> which defines  only those domain names which need to scraped and <b>parse</b> is a method which is called when any response comes from lodged requests. These attributes are important because these constitute the base of Spider definitions.

# %% [markdown]
# #### c. Lets Scrap
# Dalam melakukan scrapping terdapat 3 hal yang perlu dilakukan yaitu:
# 1. Melakukan update <b>items.py</b> dengan mengisi field yang akan di extract.
# 2. Membuat sebuah <b>Spider</b> baru untuk mendefinisikan <b>allowed_domains, start_urls, parse</b> method
# 3. Melakukan update <b>pipelines.py</b> untuk data processing lebih jauh.
#
# Sekarang ayo kita melakukan scrapping.

# %% [markdown]
# - Update <b>items.py</b>
# <br>
# Update file <b>items.py</b> menggunakan notepad dengan kode di bawah ini

# %% [raw]
# # -*- coding: utf-8 -*-
#
# # Define here the models for your scraped items
# #
# # See documentation in:
# # http://doc.scrapy.org/en/latest/topics/items.html
#
# import scrapy
#
#
# class BukalapakItem(scrapy.Item):
#     # define the fields for your item here like:
#     product_name = scrapy.Field()
#     product_category = scrapy.Field()
#     product_currency_price = scrapy.Field()
#     product_price = scrapy.Field()

# %% [markdown]
# - Create new <b>Spider</b>
# Untuk membuatnya, kita bisa menggunakan default utility <b>genspider</b>. Lakukan hal tersebut pada <b>console</b>. Untuk melakukan hal ini terlebih dahulu masuk ke dalam directory <b>bukalapak</b> dengan perinyah <b>cd bukalapak</b>
# <br><br><b><pre>
# scrapy genspider BukalapakProductSpider bukalapak.com
# </pre></b><br>

# %% [markdown]
# - Update <b>BukalapakProductSpider.py</b>

# %% [raw]
# import scrapy
# from bukalapak.items import BukalapakItem
#
# class BukalapakProductSpider(scrapy.Spider):
#     name = "BukalapakDeals"
#     allowed_domains = ["bukalapak.com"]
#
#     #Use working product URL below
#     start_urls = [
#         "https://www.bukalapak.com/p/komputer/laptop/43mglk-jual-laptop-hp-8560w-elitebook-workstation-core-i7",
#         "https://www.bukalapak.com/p/komputer/laptop/3sz46v-jual-hp-1000",
#         "https://www.bukalapak.com/p/komputer/laptop/43ohlq-jual-dell-e6420-core-i5",
#         "https://www.bukalapak.com/p/komputer/laptop/45uqjz-jual-macbook-white-core-2-duo-mulus-normal-lancar"
#     ]
#
#     def parse(self, response):
#         items = BukalapakItem()
#         name = response.xpath('//h1[@itemprop="name"]/text()').extract()
#         category = response.xpath('//dd[@itemprop="category"]/text()').extract()
#         currency_price = response.xpath('//span[@itemprop="priceCurrency"]/text()').extract()
#         price = response.xpath('//span[@itemprop="price"]/text()').extract()
#
#         items['product_name'] = ''.join(name).strip()
#         items['product_category'] = ''.join(category).strip()
#         items['product_currency_price'] = ''.join(currency_price).strip()
#         items['product_price'] = ''.join(price).strip()
#
#         yield items

# %% [markdown]
# - Pipeline<br>
# Pipeline classes implement <b>process_item</b> method which is called each and every time whenever items is being yielded by a Spider. It takes <b>item</b> and <b>spider</b> class as arguments and returns a <b>dict</b> object. So for this example, we are just returning item dict as it is.
# <br><br>
# Untuk menggunakan <b>pipeline</b> terlebih dahulu melakukan enable pada <b>settings.py</b>

# %% [raw]
# # Configure item pipelines
# # See http://scrapy.readthedocs.org/en/latest/topics/item-pipeline.html
# ITEM_PIPELINES = {
#     'bukalapak.pipelines.BukalapakPipeline': 300,
# }

# %% [markdown]
# - Melakukan <b>crawling</b>
# Untuk melakukan crawing dan menyimpannya pada sebuah file json, gunakan perintah berikut
# <br><br><b>scrapy crawl BukalapakDeals -o items.json</b><br><br>
# Berikut output yang dihasilkan pada <b>items.json</b>

# %% [raw]
# [
# {"product_category": "Laptop", "product_price": "6.000.000", "product_name": "Laptop HP 8560W EliteBook Workstation Core i7", "product_currency_price": "Rp"},
# {"product_category": "Laptop", "product_price": "2.400.000", "product_name": "HP 1000", "product_currency_price": "Rp"},
# {"product_category": "Laptop", "product_price": "3.200.000", "product_name": "DELL E6420 CORE I5", "product_currency_price": "Rp"},
# {"product_category": "Laptop", "product_price": "2.950.000", "product_name": "Macbook White Core 2 Duo Mulus , Normal,  Lancar", "product_currency_price": "Rp"}
# ]
